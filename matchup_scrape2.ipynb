# %%
import requests
import pandas as pd
import time
import os
from datetime import datetime
import sys
import json
import tempfile
import shutil
from typing import Dict, Set, Tuple, Optional
import logging

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('scraper.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

class SafeJSONManager:
    """
    Manages JSON files with atomic writes and corruption recovery
    """
    
    @staticmethod
    def safe_write_json(data: dict, filepath: str, backup_count: int = 3) -> bool:
        """
        Safely write JSON data with atomic operations and backups
        """
        try:
            # Create backup of existing file if it exists
            if os.path.exists(filepath) and backup_count > 0:
                SafeJSONManager._rotate_backups(filepath, backup_count)
            
            # Write to temporary file first
            temp_filepath = f"{filepath}.tmp"
            with open(temp_filepath, 'w') as f:
                json.dump(data, f, indent=2)
            
            # Atomic move to final location
            shutil.move(temp_filepath, filepath)
            
            # Verify the file can be read back
            with open(filepath, 'r') as f:
                json.load(f)
            
            return True
            
        except Exception as e:
            logger.error(f"Error safely writing JSON to {filepath}: {e}")
            # Clean up temp file if it exists
            if os.path.exists(f"{filepath}.tmp"):
                try:
                    os.remove(f"{filepath}.tmp")
                except:
                    pass
            return False
    
    @staticmethod
    def _rotate_backups(filepath: str, backup_count: int):
        """
        Rotate backup files, keeping the most recent N backups
        """
        # Rotate existing backups
        for i in range(backup_count - 1, 0, -1):
            old_backup = f"{filepath}.backup{i}"
            new_backup = f"{filepath}.backup{i + 1}"
            if os.path.exists(old_backup):
                if os.path.exists(new_backup):
                    os.remove(new_backup)
                shutil.move(old_backup, new_backup)
        
        # Create new backup from current file
        if os.path.exists(filepath):
            backup_path = f"{filepath}.backup1"
            if os.path.exists(backup_path):
                os.remove(backup_path)
            shutil.copy2(filepath, backup_path)
    
    @staticmethod
    def safe_load_json(filepath: str) -> dict:
        """
        Safely load JSON with automatic corruption recovery
        """
        if not os.path.exists(filepath):
            logger.info(f"No existing JSON file found at {filepath}")
            return {}
        
        # Try to load the main file
        try:
            with open(filepath, 'r') as f:
                data = json.load(f)
            logger.info(f"Successfully loaded JSON from {filepath} with {len(data)} entries")
            return data
        except json.JSONDecodeError as e:
            logger.warning(f"JSON corruption detected in {filepath}: {e}")
            return SafeJSONManager._recover_from_corruption(filepath)
        except Exception as e:
            logger.error(f"Unexpected error loading {filepath}: {e}")
            return SafeJSONManager._recover_from_corruption(filepath)
    
    @staticmethod
    def _recover_from_corruption(filepath: str) -> dict:
        """
        Attempt to recover from JSON corruption using backups
        """
        logger.info("Attempting JSON corruption recovery...")
        
        # Try backup files
        for i in range(1, 6):  # Try up to 5 backups
            backup_path = f"{filepath}.backup{i}"
            if os.path.exists(backup_path):
                try:
                    with open(backup_path, 'r') as f:
                        data = json.load(f)
                    logger.info(f"Successfully recovered from backup {backup_path} with {len(data)} entries")
                    
                    # Restore the good backup as the main file
                    shutil.copy2(backup_path, filepath)
                    return data
                except json.JSONDecodeError:
                    logger.warning(f"Backup {backup_path} is also corrupted, trying next...")
                    continue
                except Exception as e:
                    logger.warning(f"Error reading backup {backup_path}: {e}")
                    continue
        
        # If all backups failed, try manual recovery
        logger.warning("All backups failed, attempting manual recovery...")
        return SafeJSONManager._manual_recovery(filepath)
    
    @staticmethod
    def _manual_recovery(filepath: str) -> dict:
        """
        Last resort: try to manually recover what we can from corrupted JSON
        """
        try:
            with open(filepath, 'r') as f:
                content = f.read()
            
            # Try to find complete entries using regex
            import re
            pattern = r'"(\d+_\d+)"\s*:\s*(\{(?:[^{}]|(?:\{[^{}]*\}))*\})'
            matches = re.finditer(pattern, content)
            
            recovered_data = {}
            for match in matches:
                key = match.group(1)
                entry_json = match.group(2)
                try:
                    entry_data = json.loads(entry_json)
                    recovered_data[key] = entry_data
                except json.JSONDecodeError:
                    continue
            
            if recovered_data:
                logger.info(f"Manual recovery found {len(recovered_data)} entries")
                return recovered_data
            else:
                logger.warning("Manual recovery found no valid entries")
                return {}
                
        except Exception as e:
            logger.error(f"Manual recovery failed: {e}")
            return {}

class ImprovedNBAScraper:
    """
    Improved NBA video details scraper with enhanced error handling and corruption resistance
    """
    
    def __init__(self, master_record_path: str, output_dir: str = "scraped_data", 
                 log_file: str = "scrape_log.json"):
        self.master_record_path = master_record_path
        self.output_dir = output_dir
        self.log_file = log_file
        self.json_manager = SafeJSONManager()
        
        # Load master record
        self.master_record = self._load_master_record()
        
        # Load scrape log
        self.log_data = self.json_manager.safe_load_json(self.log_file)
        
        # Migrate CSV data to log if needed
        self._migrate_csv_data_to_log()
    
    def _load_master_record(self) -> pd.DataFrame:
        """Load and prepare master record"""
        try:
            df = pd.read_csv(self.master_record_path)
            df['TEAM_ID'] = df['TEAM_ID'].astype(int)
            df['PLAYER_ID'] = df['PLAYER_ID'].astype(int)
            df = df[df.year >= 2019]
            logger.info(f"Loaded master record with {len(df)} rows")
            return df
        except Exception as e:
            logger.error(f"Error loading master record: {e}")
            raise
    
    def _migrate_csv_data_to_log(self):
        """Migrate existing CSV data to log"""
        csv_combinations = self._load_existing_csv_combinations()
        if not csv_combinations:
            return
        
        migrated_count = 0
        for player_id, game_id in csv_combinations:
            key = f"{player_id}_{game_id}"
            if key not in self.log_data:
                self.log_data[key] = {
                    "player_id": str(player_id),
                    "game_id": str(game_id),
                    "team_id": "unknown",
                    "player_name": "unknown",
                    "year": 2025,
                    "timestamp": "migrated_from_csv",
                    "success": True,
                    "record_count": 1,
                    "has_data": True,
                    "error_msg": None
                }
                migrated_count += 1
        
        if migrated_count > 0:
            logger.info(f"Migrated {migrated_count} successful scrapes from CSV files to log")
            self._save_log()
    
    def _load_existing_csv_combinations(self) -> Set[Tuple[str, str]]:
        """Load all existing player-game combinations from CSV files"""
        if not os.path.exists(self.output_dir):
            return set()
        
        combinations = set()
        year_dirs = [d for d in os.listdir(self.output_dir) 
                    if d.startswith('year_') and os.path.isdir(os.path.join(self.output_dir, d))]
        
        for year_dir in year_dirs:
            year_path = os.path.join(self.output_dir, year_dir)
            year = year_dir.replace('year_', '')
            
            # Check combined file first
            combined_file = os.path.join(year_path, f"combined_video_details_{year}.csv")
            if os.path.exists(combined_file):
                try:
                    df = pd.read_csv(combined_file)
                    if 'def_id' in df.columns and 'gi' in df.columns:
                        year_combinations = set(zip(df['def_id'].astype(str), df['gi'].astype(str)))
                        combinations.update(year_combinations)
                except Exception as e:
                    logger.warning(f"Error reading {combined_file}: {e}")
            else:
                # Check batch files
                batch_files = [f for f in os.listdir(year_path) 
                             if f.startswith('batch_') and f.endswith('.csv')]
                for batch_file in batch_files:
                    try:
                        batch_path = os.path.join(year_path, batch_file)
                        df = pd.read_csv(batch_path)
                        if 'def_id' in df.columns and 'gi' in df.columns:
                            batch_combinations = set(zip(df['def_id'].astype(str), df['gi'].astype(str)))
                            combinations.update(batch_combinations)
                    except Exception as e:
                        logger.warning(f"Error reading {batch_path}: {e}")
        
        logger.info(f"Found {len(combinations)} existing combinations in CSV files")
        return combinations
    
    def _save_log(self) -> bool:
        """Safely save the scrape log"""
        return self.json_manager.safe_write_json(self.log_data, self.log_file)
    
    def _update_log(self, player_id: str, game_id: str, team_id: str, player_name: str, 
                   year: int, success: bool, record_count: int = 0, has_data: bool = None, 
                   error_msg: str = None):
        """Update the scrape log with a new attempt"""
        key = f"{player_id}_{game_id}"
        self.log_data[key] = {
            "player_id": str(player_id),
            "game_id": str(game_id),
            "team_id": str(team_id),
            "player_name": player_name,
            "year": year,
            "timestamp": datetime.now().isoformat(),
            "success": success,
            "record_count": record_count,
            "has_data": has_data if has_data is not None else (record_count > 0),
            "error_msg": error_msg
        }
    
    def _fetch_video_details(self, game_id: str, player_id: str, team_id: str, 
                           context_measure: str = "DEF_FGA") -> Optional[dict]:
        """Fetch video details from NBA API with improved error handling"""
        base_url = "https://stats.nba.com/stats/videodetailsasset"
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
            "Referer": "https://www.nba.com",
            "Accept": "application/json",
            "Accept-Language": "en-US,en;q=0.9",
            "Origin": "https://www.nba.com"
        }
        
        params = {
            "GameID": f"00{game_id}",
            "GameEventID": "",
            "PlayerID": str(player_id),
            "TeamID": str(team_id),
            "Season": "",
            "SeasonType": "",
            "AheadBehind": "",
            "CFID": "",
            "CFPARAMS": "",
            "ClutchTime": "",
            "Conference": "",
            "ContextFilter": "",
            "ContextMeasure": context_measure,
            "DateFrom": "",
            "DateTo": "",
            "Division": "",
            "EndPeriod": 0,
            "EndRange": 40800,
            "GROUP_ID": "",
            "GameSegment": "",
            "GroupID": "",
            "GroupMode": "",
            "GroupQuantity": 5,
            "LastNGames": 0,
            "Location": "",
            "Month": 0,
            "OnOff": "",
            "OppPlayerID": "",
            "OpponentTeamID": 0,
            "Outcome": "",
            "PORound": 0,
            "Period": 0,
            "PlayerID1": "",
            "PlayerID2": "",
            "PlayerID3": "",
            "PlayerID4": "",
            "PlayerID5": "",
            "PlayerPosition": "",
            "PointDiff": "",
            "Position": "",
            "RangeType": 0,
            "RookieYear": "",
            "SeasonSegment": "",
            "ShotClockRange": "",
            "StartPeriod": 0,
            "StartRange": 0,
            "StarterBench": "",
            "VsConference": "",
            "VsDivision": "",
            "VsPlayerID1": "",
            "VsPlayerID2": "",
            "VsPlayerID3": "",
            "VsPlayerID4": "",
            "VsPlayerID5": "",
            "VsTeamID": ""
        }
        
        max_retries = 3
        base_delay = 1
        
        for attempt in range(max_retries):
            try:
                response = requests.get(base_url, headers=headers, params=params, timeout=30)
                
                if response.status_code == 200:
                    return response.json()
                elif response.status_code == 429:  # Rate limited
                    delay = base_delay * (2 ** attempt)
                    logger.warning(f"Rate limited for Player {player_id}, Game {game_id}. Waiting {delay}s...")
                    time.sleep(delay)
                    continue
                else:
                    logger.warning(f"Request failed with status {response.status_code} for Player {player_id}, Game {game_id}")
                    if attempt == max_retries - 1:
                        return None
                    
            except requests.RequestException as e:
                logger.warning(f"Request error for Player {player_id}, Game {game_id} (attempt {attempt + 1}): {e}")
                if attempt == max_retries - 1:
                    return None
                time.sleep(base_delay * (attempt + 1))
        
        return None
    
    def _process_video_data(self, video_json: dict, player_id: str, team_id: str, 
                          player_name: str, year: int) -> Optional[pd.DataFrame]:
        """Process video JSON response into DataFrame"""
        try:
            if not (video_json and 'resultSets' in video_json and 'playlist' in video_json['resultSets']):
                return None
            
            playlist = video_json['resultSets']['playlist']
            if not playlist:
                return None
            
            df = pd.DataFrame(playlist)
            if df.empty or not all(col in df.columns for col in ['gi', 'ei', 'dsc']):
                return None
            
            df = df[['gi', 'ei', 'dsc']]
            df['def_id'] = player_id
            df['team_id'] = team_id
            df['player_name'] = player_name
            df['year'] = year
            return df
            
        except Exception as e:
            logger.error(f"Error processing video data for Player {player_id}: {e}")
            return None
    
    def _save_batch_data(self, year_data_dict: Dict[int, list], batch_num: int) -> int:
        """Save batch data organized by year with improved error handling"""
        if not os.path.exists(self.output_dir):
            os.makedirs(self.output_dir)
        
        total_records_saved = 0
        
        for year, data_list in year_data_dict.items():
            if not data_list:
                continue
            
            try:
                # Create year directory
                year_dir = os.path.join(self.output_dir, f"year_{year}")
                os.makedirs(year_dir, exist_ok=True)
                
                # Combine data
                combined_df = pd.concat(data_list, ignore_index=True)
                
                # Save with atomic write
                filename = f"batch_{batch_num}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
                filepath = os.path.join(year_dir, filename)
                temp_filepath = f"{filepath}.tmp"
                
                # Write to temp file first
                combined_df.to_csv(temp_filepath, index=False)
                
                # Atomic move
                shutil.move(temp_filepath, filepath)
                
                records_count = len(combined_df)
                total_records_saved += records_count
                logger.info(f"Saved {year} batch {batch_num} with {records_count} records to {filename}")
                
            except Exception as e:
                logger.error(f"Error saving batch data for year {year}: {e}")
                # Clean up temp file if it exists
                temp_path = os.path.join(year_dir, f"batch_{batch_num}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv.tmp")
                if os.path.exists(temp_path):
                    try:
                        os.remove(temp_path)
                    except:
                        pass
        
        return total_records_saved
    
    def analyze_scrape_status(self):
        """Analyze current scrape status"""
        unique_combinations = self.master_record[['PLAYER_ID', 'GAME_ID', 'TEAM_ID', 'PLAYER_NAME', 'year']].drop_duplicates()
        total_combinations = len(unique_combinations)
        
        unique_combinations['scrape_key'] = unique_combinations['PLAYER_ID'].astype(str) + "_" + unique_combinations['GAME_ID'].astype(str)
        
        def categorize_attempt(scrape_key):
            if scrape_key not in self.log_data:
                return 'never_attempted'
            entry = self.log_data[scrape_key]
            if not entry['success']:
                return 'failed'
            elif entry.get('has_data', entry['record_count'] > 0):
                return 'successful_with_data'
            else:
                return 'successful_no_data'
        
        unique_combinations['log_status'] = unique_combinations['scrape_key'].apply(categorize_attempt)
        
        status_counts = unique_combinations['log_status'].value_counts()
        
        logger.info("=== SCRAPE STATUS ANALYSIS ===")
        logger.info(f"Total combinations: {total_combinations}")
        for status, count in status_counts.items():
            logger.info(f"{status}: {count} combinations")
        
        # Show breakdown by year
        for status in status_counts.index:
            status_data = unique_combinations[unique_combinations['log_status'] == status]
            if len(status_data) > 0:
                logger.info(f"\n{status} by year:")
                year_counts = status_data['year'].value_counts().sort_index()
                for year, count in year_counts.items():
                    logger.info(f"  {year}: {count} combinations")
        
        return unique_combinations
    
    def scrape(self, context_measure: str = "DEF_FGA", delay_between_requests: float = 2.0,
              batch_size: int = 50, save_log_frequency: int = 10, 
              force_retry_failed: bool = False, retry_no_data: bool = False):
        """
        Main scraping function with improved error handling and progress tracking
        """
        logger.info("=== STARTING IMPROVED NBA VIDEO SCRAPER ===")
        
        # Analyze current status
        unique_combinations = self.analyze_scrape_status()
        
        # Determine what to scrape
        to_scrape_parts = [unique_combinations[unique_combinations['log_status'] == 'never_attempted']]
        
        if force_retry_failed:
            failed_combinations = unique_combinations[unique_combinations['log_status'] == 'failed']
            to_scrape_parts.append(failed_combinations)
            logger.info(f"Force retry failed enabled: Including {len(failed_combinations)} failed attempts")
        
        if retry_no_data:
            no_data_combinations = unique_combinations[unique_combinations['log_status'] == 'successful_no_data']
            to_scrape_parts.append(no_data_combinations)
            logger.info(f"Retry no data enabled: Including {len(no_data_combinations)} no-data attempts")
        
        to_scrape_df = pd.concat(to_scrape_parts) if len(to_scrape_parts) > 1 else to_scrape_parts[0]
        
        if len(to_scrape_df) == 0:
            logger.info("🎉 No combinations to scrape!")
            return
        
        logger.info(f"Will attempt {len(to_scrape_df)} combinations")
        
        # Initialize tracking variables
        year_data = {}
        successful_requests = 0
        failed_requests = 0
        no_data_requests = 0
        batch_num = self._get_next_batch_number()
        total_records_saved = 0
        
        logger.info(f"Starting with batch number: {batch_num}")
        
        # Process each combination
        for idx, (_, row) in enumerate(to_scrape_df.iterrows()):
            try:
                player_id = str(row['PLAYER_ID'])
                game_id = str(row['GAME_ID'])
                team_id = str(row['TEAM_ID'])
                player_name = row['PLAYER_NAME']
                year = row['year']
                
                if (idx + 1) % 50 == 0:
                    logger.info(f"Processing {idx + 1}/{len(to_scrape_df)}: Player {player_name} ({player_id}) in Game {game_id} - {year}")
                
                # Fetch video details
                video_json = self._fetch_video_details(game_id, player_id, team_id, context_measure)
                
                if video_json:
                    processed_df = self._process_video_data(video_json, player_id, team_id, player_name, year)
                    
                    if processed_df is not None and not processed_df.empty:
                        if year not in year_data:
                            year_data[year] = []
                        
                        year_data[year].append(processed_df)
                        successful_requests += 1
                        record_count = len(processed_df)
                        
                        self._update_log(player_id, game_id, team_id, player_name, year, 
                                       True, record_count, has_data=True)
                    else:
                        no_data_requests += 1
                        self._update_log(player_id, game_id, team_id, player_name, year, 
                                       True, 0, has_data=False)
                else:
                    failed_requests += 1
                    self._update_log(player_id, game_id, team_id, player_name, year, 
                                   False, 0, error_msg="API request failed")
                
                # Save log periodically
                if (idx + 1) % save_log_frequency == 0:
                    if not self._save_log():
                        logger.error(f"Failed to save log at iteration {idx + 1}")
                
                # Save batch data when threshold is reached
                if successful_requests > 0 and successful_requests % batch_size == 0:
                    records_saved = self._save_batch_data(year_data, batch_num)
                    total_records_saved += records_saved
                    year_data = {}
                    batch_num += 1
                
                # Rate limiting
                if idx < len(to_scrape_df) - 1:
                    time.sleep(delay_between_requests)
                    
            except KeyboardInterrupt:
                logger.info("Scraping interrupted by user. Saving progress...")
                break
            except Exception as e:
                logger.error(f"Unexpected error processing row {idx}: {e}")
                continue
        
        # Save any remaining data
        if any(year_data.values()):
            records_saved = self._save_batch_data(year_data, batch_num)
            total_records_saved += records_saved
        
        # Final log save
        if not self._save_log():
            logger.error("Failed to save final log")
        
        # Print summary
        logger.info("=== SCRAPING COMPLETE ===")
        logger.info(f"Attempted to scrape: {len(to_scrape_df)}")
        logger.info(f"Successful requests with data: {successful_requests}")
        logger.info(f"Successful requests with no data: {no_data_requests}")
        logger.info(f"Failed requests: {failed_requests}")
        logger.info(f"New video records saved: {total_records_saved}")
        
        if len(to_scrape_df) > 0:
            success_rate = ((successful_requests + no_data_requests) / len(to_scrape_df)) * 100
            logger.info(f"Overall success rate: {success_rate:.1f}%")
            if successful_requests > 0:
                data_rate = (successful_requests / len(to_scrape_df)) * 100
                logger.info(f"Data found rate: {data_rate:.1f}%")
    
    def _get_next_batch_number(self) -> int:
        """Get the next batch number by examining existing files"""
        if not os.path.exists(self.output_dir):
            return 1
        
        existing_batches = []
        for year_dir in os.listdir(self.output_dir):
            if year_dir.startswith('year_'):
                year_path = os.path.join(self.output_dir, year_dir)
                if os.path.isdir(year_path):
                    batch_files = [f for f in os.listdir(year_path) if f.startswith('batch_')]
                    for batch_file in batch_files:
                        try:
                            batch_num_str = batch_file.split('_')[1]
                            existing_batches.append(int(batch_num_str))
                        except (ValueError, IndexError):
                            pass
        
        return max(existing_batches) + 1 if existing_batches else 1
    
    def combine_batches_by_year(self):
        """Combine all batch files within each year into a single CSV per year"""
        if not os.path.exists(self.output_dir):
            logger.info(f"Output directory {self.output_dir} does not exist")
            return
        
        year_dirs = [d for d in os.listdir(self.output_dir) 
                    if d.startswith('year_') and os.path.isdir(os.path.join(self.output_dir, d))]
        
        if not year_dirs:
            logger.info("No year directories found")
            return
        
        logger.info(f"Found {len(year_dirs)} year directories")
        
        for year_dir in sorted(year_dirs):
            year_path = os.path.join(self.output_dir, year_dir)
            year = year_dir.replace('year_', '')
            
            # Check if combined file already exists
            combined_file = os.path.join(year_path, f"combined_video_details_{year}.csv")
            if os.path.exists(combined_file):
                logger.info(f"Combined file already exists for {year}, skipping...")
                continue
            
            # Find batch files
            batch_files = [f for f in os.listdir(year_path) 
                         if f.startswith('batch_') and f.endswith('.csv')]
            
            if not batch_files:
                logger.info(f"No batch files found for {year}")
                continue
            
            logger.info(f"Processing {year}: Found {len(batch_files)} batch files")
            
            try:
                # Load and combine all batches
                year_batches = []
                for file in batch_files:
                    file_path = os.path.join(year_path, file)
                    df = pd.read_csv(file_path)
                    year_batches.append(df)
                
                if year_batches:
                    final_df = pd.concat(year_batches, ignore_index=True)
                    
                    # Remove duplicates
                    initial_count = len(final_df)
                    final_df = final_df.drop_duplicates()
                    final_count = len(final_df)
                    
                    if initial_count != final_count:
                        logger.info(f"Removed {initial_count - final_count} duplicate records for {year}")
                    
                    # Save with atomic write
                    temp_path = f"{combined_file}.tmp"
                    final_df.to_csv(temp_path, index=False)
                    shutil.move(temp_path, combined_file)
                    
                    logger.info(f"✓ Combined file saved: {combined_file} with {final_count} total records")
                    
            except Exception as e:
                logger.error(f"Error combining batches for {year}: {e}")
    
    def get_summary(self):
        """Print a summary of collected data by year."""
        if not os.path.exists(self.output_dir):
            logger.info(f"Output directory {self.output_dir} does not exist.")
            return

        year_dirs = [d for d in os.listdir(self.output_dir)
                     if d.startswith('year_') and os.path.isdir(os.path.join(self.output_dir, d))]

        if not year_dirs:
            logger.info("No year directories found.")
            return

        logger.info("\n=== DATA SUMMARY BY YEAR ===")
        total_records = 0

        for year_dir in sorted(year_dirs):
            year = year_dir.replace('year_', '')
            year_path = os.path.join(self.output_dir, year_dir)

            # Look for combined file first, otherwise count batch files
            combined_file = os.path.join(year_path, f"combined_video_details_{year}.csv")

            if os.path.exists(combined_file):
                try:
                    df = pd.read_csv(combined_file)
                    record_count = len(df)
                    logger.info(f"{year}: {record_count:,} records (combined)")
                except Exception as e:
                    logger.warning(f"Error reading combined file {combined_file}: {e}")
                    record_count = 0 # reset record count if there was an error
            else:
                # Count records in batch files
                batch_files = [f for f in os.listdir(year_path) if f.startswith('batch_') and f.endswith('.csv')]
                record_count = 0
                num_batch_files = 0
                for file in batch_files:
                    file_path = os.path.join(year_path, file)
                    try:
                        df = pd.read_csv(file_path)
                        record_count += len(df)
                        num_batch_files += 1
                    except Exception as e:
                        logger.warning(f"Error reading batch file {file_path}: {e}")
                logger.info(f"{year}: {record_count:,} records ({num_batch_files} batch files)")
            
            total_records += record_count

        logger.info(f"\nTotal records across all years: {total_records:,}")

    def analyze_log_summary(self):
        """
        Analyze the scrape log and provide statistics, replacing the old analyze_scrape_log function.
        """
        log_data = self.json_manager.safe_load_json(self.log_file) # Use the class's safe loader
        
        if not log_data:
            logger.info("No scrape log data found.")
            return
        
        successful = sum(1 for entry in log_data.values() if entry['success'])
        failed = len(log_data) - successful
        total_records_found = sum(entry.get('record_count', 0) for entry in log_data.values() if entry['success']) # Renamed to avoid confusion with `total_records` in `get_summary`
        
        logger.info("\n=== SCRAPE LOG ANALYSIS ===")
        logger.info(f"Total attempts logged: {len(log_data)}")
        logger.info(f"Successful attempts: {successful}")
        logger.info(f"Failed attempts: {failed}")
        
        if len(log_data) > 0: # Avoid division by zero
            success_rate = (successful / len(log_data)) * 100
            logger.info(f"Success rate: {success_rate:.1f}%")
        else:
            logger.info("Success rate: N/A (no attempts logged)")
            
        logger.info(f"Total video records recorded in log: {total_records_found}") # Clarified output
        
        # Analyze by year if available
        year_stats = {}
        for entry in log_data.values():
            year = entry.get('year', 'unknown')
            if year not in year_stats:
                year_stats[year] = {'attempts': 0, 'success': 0, 'records': 0}
            year_stats[year]['attempts'] += 1
            if entry['success']:
                year_stats[year]['success'] += 1
                year_stats[year]['records'] += entry.get('record_count', 0)
        
        logger.info("\nBreakdown by year:")
        
        # Separate numeric years from non-numeric ones for proper sorting
        numeric_years = []
        non_numeric_years = []
        
        for year in year_stats.keys():
            try:
                numeric_years.append(int(year))
            except (ValueError, TypeError):
                non_numeric_years.append(str(year))
        
        sorted_years = sorted(numeric_years) + sorted(non_numeric_years)
        
        for year in sorted_years:
            stats = year_stats[year]
            success_rate = (stats['success'] / stats['attempts']) * 100 if stats['attempts'] > 0 else 0
            logger.info(f"  {year}: {stats['attempts']} attempts, {stats['success']} successful ({success_rate:.1f}%), {stats['records']} records")


# Example usage
if __name__ == "__main__":
    scraper = ImprovedNBAScraper(
        master_record_path='master_record.csv',
        output_dir='scraped_data',
        log_file='scrape_log.json'
    )

    # Analyze existing log
    scraper.analyze_log_summary()

    # Run the scraper (set force_retry_failed=True to retry previously failed attempts)
    scraper.scrape(
        context_measure="DEF_FGA",
        delay_between_requests=0.001,  # 2 seconds between requests
        batch_size=50,  # Save every 50 successful requests
        force_retry_failed=False,  # Set to True to retry failed attempts
        retry_no_data=False # Set to True to retry successful attempts that found no data
    )

    # Combine all batch files by year
    scraper.combine_batches_by_year()

    # Print summary of collected data
    scraper.get_summary()
    
    # Final log analysis
    scraper.analyze_log_summary()
# Out:
# 2025-06-20 15:51:07,603 - INFO - Loaded master record with 188540 rows
# 2025-06-20 15:51:08,057 - INFO - Successfully loaded JSON from scrape_log.json with 187896 entries
# 2025-06-20 15:51:11,468 - INFO - Found 173579 existing combinations in CSV files
# 2025-06-20 15:51:12,123 - INFO - Successfully loaded JSON from scrape_log.json with 187896 entries
# 2025-06-20 15:51:12,153 - INFO -
# === SCRAPE LOG ANALYSIS ===
# 2025-06-20 15:51:12,154 - INFO - Total attempts logged: 187896
# 2025-06-20 15:51:12,156 - INFO - Successful attempts: 187812
# 2025-06-20 15:51:12,158 - INFO - Failed attempts: 84
# 2025-06-20 15:51:12,159 - INFO - Success rate: 100.0%
# 2025-06-20 15:51:12,160 - INFO - Total video records recorded in log: 445273
# 2025-06-20 15:51:12,219 - INFO -
# Breakdown by year:
# 2025-06-20 15:51:12,220 - INFO -   2019: 2272 attempts, 2267 successful (99.8%), 220 records
# 2025-06-20 15:51:12,221 - INFO -   2020: 10048 attempts, 10048 successful (100.0%), 78541 records
# 2025-06-20 15:51:12,222 - INFO -   2021: 24915 attempts, 24913 successful (100.0%), 219375 records
# 2025-06-20 15:51:12,224 - INFO -   2022: 2568 attempts, 2568 successful (100.0%), 1134 records
# 2025-06-20 15:51:12,225 - INFO -   2023: 2384 attempts, 2384 successful (100.0%), 1204 records
# 2025-06-20 15:51:12,226 - INFO -   2024: 2493 attempts, 2493 successful (100.0%), 1497 records
# 2025-06-20 15:51:12,227 - INFO -   2025: 143216 attempts, 143139 successful (99.9%), 143302 records
# 2025-06-20 15:51:12,244 - INFO - === STARTING IMPROVED NBA VIDEO SCRAPER ===
# 2025-06-20 15:51:12,476 - INFO - === SCRAPE STATUS ANALYSIS ===
# 2025-06-20 15:51:12,478 - INFO - Total combinations: 188540
# 2025-06-20 15:51:12,479 - INFO - successful_with_data: 173889 combinations
# 2025-06-20 15:51:12,479 - INFO - successful_no_data: 13923 combinations
# 2025-06-20 15:51:12,480 - INFO - never_attempted: 644 combinations
# 2025-06-20 15:51:12,481 - INFO - failed: 84 combinations
# 2025-06-20 15:51:12,500 - INFO -
# successful_with_data by year:
# 2025-06-20 15:51:12,503 - INFO -   2019: 25612 combinations
# 2025-06-20 15:51:12,504 - INFO -   2020: 22287 combinations
# 2025-06-20 15:51:12,505 - INFO -   2021: 22921 combinations
# 2025-06-20 15:51:12,506 - INFO -   2022: 25490 combinations
# 2025-06-20 15:51:12,507 - INFO -   2023: 25358 combinations
# 2025-06-20 15:51:12,508 - INFO -   2024: 25758 combinations
# 2025-06-20 15:51:12,509 - INFO -   2025: 26463 combinations
# 2025-06-20 15:51:12,523 - INFO -
# successful_no_data by year:
# 2025-06-20 15:51:12,524 - INFO -   2019: 2245 combinations
# 2025-06-20 15:51:12,525 - INFO -   2020: 1800 combinations
# 2025-06-20 15:51:12,527 - INFO -   2021: 1992 combinations
# 2025-06-20 15:51:12,527 - INFO -   2022: 2440 combinations
# 2025-06-20 15:51:12,528 - INFO -   2023: 2264 combinations
# 2025-06-20 15:51:12,529 - INFO -   2024: 2328 combinations
# 2025-06-20 15:51:12,530 - INFO -   2025: 854 combinations
# 2025-06-20 15:51:12,543 - INFO -
# never_attempted by year:
# 2025-06-20 15:51:12,545 - INFO -   2025: 644 combinations
# 2025-06-20 15:51:12,556 - INFO -
# failed by year:
# 2025-06-20 15:51:12,557 - INFO -   2019: 5 combinations
# 2025-06-20 15:51:12,558 - INFO -   2021: 2 combinations
# 2025-06-20 15:51:12,559 - INFO -   2025: 77 combinations
# 2025-06-20 15:51:12,572 - INFO - Will attempt 644 combinations
# 2025-06-20 15:51:12,576 - INFO - Starting with batch number: 3785
# 2025-06-20 15:51:12,726 - WARNING - Request failed with status 500 for Player 203081, Game 22401012
# 2025-06-20 15:51:12,868 - WARNING - Request failed with status 500 for Player 203081, Game 22401012
# 2025-06-20 15:51:13,040 - WARNING - Request failed with status 500 for Player 203081, Game 22401012
# 2025-06-20 15:51:16,635 - WARNING - Request failed with status 500 for Player 1626181, Game 22400997
# 2025-06-20 15:51:17,057 - WARNING - Request failed with status 500 for Player 1626181, Game 22400997
# 2025-06-20 15:51:17,201 - WARNING - Request failed with status 500 for Player 1626181, Game 22400997
# 2025-06-20 15:51:17,889 - WARNING - Request failed with status 500 for Player 1630182, Game 22400993
# 2025-06-20 15:51:18,062 - WARNING - Request failed with status 500 for Player 1630182, Game 22400993
# 2025-06-20 15:51:18,214 - WARNING - Request failed with status 500 for Player 1630182, Game 22400993
# 2025-06-20 15:51:18,935 - WARNING - Request failed with status 500 for Player 1642259, Game 22400627
# 2025-06-20 15:51:19,089 - WARNING - Request failed with status 500 for Player 1642259, Game 22400627
# 2025-06-20 15:51:19,231 - WARNING - Request failed with status 500 for Player 1642259, Game 22400627
# 2025-06-20 15:51:19,964 - WARNING - Request failed with status 500 for Player 203932, Game 22401006
# 2025-06-20 15:51:20,135 - WARNING - Request failed with status 500 for Player 203932, Game 22401006
# 2025-06-20 15:51:20,281 - WARNING - Request failed with status 500 for Player 203932, Game 22401006
# 2025-06-20 15:51:21,179 - WARNING - Request failed with status 500 for Player 1630692, Game 22401006
# 2025-06-20 15:51:21,322 - WARNING - Request failed with status 500 for Player 1630692, Game 22401006
# 2025-06-20 15:51:21,523 - WARNING - Request failed with status 500 for Player 1630692, Game 22401006
# 2025-06-20 15:51:23,682 - WARNING - Request failed with status 500 for Player 1628415, Game 22400999
# 2025-06-20 15:51:23,892 - WARNING - Request failed with status 500 for Player 1628415, Game 22400999
# 2025-06-20 15:51:24,037 - WARNING - Request failed with status 500 for Player 1628415, Game 22400999
# 2025-06-20 15:51:24,730 - WARNING - Request failed with status 500 for Player 1630174, Game 22400998
# 2025-06-20 15:51:24,877 - WARNING - Request failed with status 500 for Player 1630174, Game 22400998
# 2025-06-20 15:51:25,024 - WARNING - Request failed with status 500 for Player 1630174, Game 22400998
# 2025-06-20 15:51:25,712 - WARNING - Request failed with status 500 for Player 1631097, Game 22400998
# 2025-06-20 15:51:25,932 - WARNING - Request failed with status 500 for Player 1631097, Game 22400998
# 2025-06-20 15:51:26,078 - WARNING - Request failed with status 500 for Player 1631097, Game 22400998
# 2025-06-20 15:51:26,829 - WARNING - Request failed with status 500 for Player 1631119, Game 22401002
# 2025-06-20 15:51:26,979 - WARNING - Request failed with status 500 for Player 1631119, Game 22401002
# 2025-06-20 15:51:27,129 - WARNING - Request failed with status 500 for Player 1631119, Game 22401002
# 2025-06-20 15:51:27,812 - WARNING - Request failed with status 500 for Player 1629656, Game 22401002
# 2025-06-20 15:51:27,998 - WARNING - Request failed with status 500 for Player 1629656, Game 22401002
# 2025-06-20 15:51:28,153 - WARNING - Request failed with status 500 for Player 1629656, Game 22401002
# 2025-06-20 15:51:28,880 - WARNING - Request failed with status 500 for Player 1642276, Game 22401000
# 2025-06-20 15:51:29,025 - WARNING - Request failed with status 500 for Player 1642276, Game 22401000
# 2025-06-20 15:51:29,214 - WARNING - Request failed with status 500 for Player 1642276, Game 22401000
# 2025-06-20 15:51:29,836 - WARNING - Request failed with status 500 for Player 1629639, Game 22401000
# 2025-06-20 15:51:30,019 - WARNING - Request failed with status 500 for Player 1629639, Game 22401000
# 2025-06-20 15:51:30,165 - WARNING - Request failed with status 500 for Player 1629639, Game 22401000
# 2025-06-20 15:51:38,622 - WARNING - Request failed with status 500 for Player 1629627, Game 22401001
# 2025-06-20 15:51:38,834 - WARNING - Request failed with status 500 for Player 1629627, Game 22401001
# 2025-06-20 15:51:38,974 - WARNING - Request failed with status 500 for Player 1629627, Game 22401001
# 2025-06-20 15:51:40,429 - WARNING - Request failed with status 500 for Player 1626157, Game 22401003
# 2025-06-20 15:51:40,652 - WARNING - Request failed with status 500 for Player 1626157, Game 22401003
# 2025-06-20 15:51:40,807 - WARNING - Request failed with status 500 for Player 1626157, Game 22401003
# 2025-06-20 15:51:41,563 - WARNING - Request failed with status 500 for Player 1628384, Game 22401003
# 2025-06-20 15:51:41,716 - WARNING - Request failed with status 500 for Player 1628384, Game 22401003
# 2025-06-20 15:51:41,868 - WARNING - Request failed with status 500 for Player 1628384, Game 22401003
# 2025-06-20 15:51:43,526 - WARNING - Request failed with status 500 for Player 1630208, Game 22401007
# 2025-06-20 15:51:43,724 - WARNING - Request failed with status 500 for Player 1630208, Game 22401007
# 2025-06-20 15:51:43,882 - WARNING - Request failed with status 500 for Player 1630208, Game 22401007
# 2025-06-20 15:51:44,705 - WARNING - Request failed with status 500 for Player 1631099, Game 22401009
# 2025-06-20 15:51:44,919 - WARNING - Request failed with status 500 for Player 1631099, Game 22401009
# 2025-06-20 15:51:45,068 - WARNING - Request failed with status 500 for Player 1631099, Game 22401009
# 2025-06-20 15:51:49,243 - WARNING - Request failed with status 500 for Player 1627751, Game 22401005
# 2025-06-20 15:51:49,415 - WARNING - Request failed with status 500 for Player 1627751, Game 22401005
# 2025-06-20 15:51:49,571 - WARNING - Request failed with status 500 for Player 1627751, Game 22401005
# 2025-06-20 15:51:50,268 - WARNING - Request failed with status 500 for Player 1630541, Game 22401005
# 2025-06-20 15:51:50,418 - WARNING - Request failed with status 500 for Player 1630541, Game 22401005
# 2025-06-20 15:51:50,618 - WARNING - Request failed with status 500 for Player 1630541, Game 22401005
# 2025-06-20 15:51:51,223 - WARNING - Request failed with status 500 for Player 1642261, Game 22400996
# 2025-06-20 15:51:51,371 - WARNING - Request failed with status 500 for Player 1642261, Game 22400996
# 2025-06-20 15:51:51,556 - WARNING - Request failed with status 500 for Player 1642261, Game 22400996
# 2025-06-20 15:51:52,170 - WARNING - Request failed with status 500 for Player 1627783, Game 22401011
# 2025-06-20 15:51:52,330 - WARNING - Request failed with status 500 for Player 1627783, Game 22401011
# 2025-06-20 15:51:52,904 - WARNING - Request failed with status 500 for Player 1627783, Game 22401011
# 2025-06-20 15:51:53,920 - WARNING - Request failed with status 500 for Player 1630182, Game 22401010
# 2025-06-20 15:51:54,226 - WARNING - Request failed with status 500 for Player 1630182, Game 22401010
# 2025-06-20 15:51:54,458 - WARNING - Request failed with status 500 for Player 1630182, Game 22401010
# 2025-06-20 15:51:58,326 - WARNING - Request failed with status 500 for Player 1630200, Game 22401013
# 2025-06-20 15:51:58,485 - WARNING - Request failed with status 500 for Player 1630200, Game 22401013
# 2025-06-20 15:51:58,634 - WARNING - Request failed with status 500 for Player 1630200, Game 22401013
# 2025-06-20 15:51:59,274 - WARNING - Request failed with status 500 for Player 1642273, Game 22401014
# 2025-06-20 15:51:59,470 - WARNING - Request failed with status 500 for Player 1642273, Game 22401014
# 2025-06-20 15:51:59,622 - WARNING - Request failed with status 500 for Player 1642273, Game 22401014
# 2025-06-20 15:52:00,637 - WARNING - Request failed with status 500 for Player 1630166, Game 22401022
# 2025-06-20 15:52:00,793 - WARNING - Request failed with status 500 for Player 1630166, Game 22401022
# 2025-06-20 15:52:00,994 - WARNING - Request failed with status 500 for Player 1630166, Game 22401022
# 2025-06-20 15:52:07,642 - WARNING - Request failed with status 500 for Player 204001, Game 22401020
# 2025-06-20 15:52:07,801 - WARNING - Request failed with status 500 for Player 204001, Game 22401020
# 2025-06-20 15:52:08,006 - WARNING - Request failed with status 500 for Player 204001, Game 22401020
# 2025-06-20 15:52:08,854 - WARNING - Request failed with status 500 for Player 203952, Game 22401015
# 2025-06-20 15:52:09,012 - WARNING - Request failed with status 500 for Player 203952, Game 22401015
# 2025-06-20 15:52:11,070 - WARNING - Request failed with status 500 for Player 203952, Game 22401015
# 2025-06-20 15:52:12,553 - WARNING - Request failed with status 500 for Player 1627826, Game 22401023
# 2025-06-20 15:52:12,712 - WARNING - Request failed with status 500 for Player 1627826, Game 22401023
# 2025-06-20 15:52:12,871 - WARNING - Request failed with status 500 for Player 1627826, Game 22401023
# 2025-06-20 15:52:12,875 - INFO - Processing 50/644: Player Kobe Brown (1641738) in Game 22401023 - 2025
# 2025-06-20 15:52:16,261 - WARNING - Request failed with status 500 for Player 203468, Game 22401016
# 2025-06-20 15:52:16,432 - WARNING - Request failed with status 500 for Player 203468, Game 22401016
# 2025-06-20 15:52:16,624 - WARNING - Request failed with status 500 for Player 203468, Game 22401016
# 2025-06-20 15:52:17,391 - WARNING - Request failed with status 500 for Player 202699, Game 22401019
# 2025-06-20 15:52:17,557 - WARNING - Request failed with status 500 for Player 202699, Game 22401019
# 2025-06-20 15:52:17,766 - WARNING - Request failed with status 500 for Player 202699, Game 22401019
# 2025-06-20 15:52:18,653 - WARNING - Request failed with status 500 for Player 1629643, Game 22401018
# 2025-06-20 15:52:18,804 - WARNING - Request failed with status 500 for Player 1629643, Game 22401018
# 2025-06-20 15:52:18,949 - WARNING - Request failed with status 500 for Player 1629643, Game 22401018
# 2025-06-20 15:52:19,858 - WARNING - Request failed with status 500 for Player 203084, Game 22401018
# 2025-06-20 15:52:20,049 - WARNING - Request failed with status 500 for Player 203084, Game 22401018
# 2025-06-20 15:52:20,195 - WARNING - Request failed with status 500 for Player 203084, Game 22401018
# 2025-06-20 15:52:23,174 - WARNING - Request failed with status 500 for Player 1626164, Game 22401021
# 2025-06-20 15:52:23,383 - WARNING - Request failed with status 500 for Player 1626164, Game 22401021
# 2025-06-20 15:52:23,525 - WARNING - Request failed with status 500 for Player 1626164, Game 22401021
# 2025-06-20 15:52:24,815 - WARNING - Request failed with status 500 for Player 1631099, Game 22401027
# 2025-06-20 15:52:24,983 - WARNING - Request failed with status 500 for Player 1631099, Game 22401027
# 2025-06-20 15:52:25,128 - WARNING - Request failed with status 500 for Player 1631099, Game 22401027
# 2025-06-20 15:52:30,447 - WARNING - Request failed with status 500 for Player 1628969, Game 22401026
# 2025-06-20 15:52:30,759 - WARNING - Request failed with status 500 for Player 1628969, Game 22401026
# 2025-06-20 15:52:30,903 - WARNING - Request failed with status 500 for Player 1628969, Game 22401026
# 2025-06-20 15:52:31,679 - WARNING - Request failed with status 500 for Player 1627783, Game 22401024
# 2025-06-20 15:52:31,915 - WARNING - Request failed with status 500 for Player 1627783, Game 22401024
# 2025-06-20 15:52:32,061 - WARNING - Request failed with status 500 for Player 1627783, Game 22401024
# 2025-06-20 15:52:34,707 - WARNING - Request failed with status 500 for Player 1630581, Game 22401028
# 2025-06-20 15:52:34,850 - WARNING - Request failed with status 500 for Player 1630581, Game 22401028
# 2025-06-20 15:52:35,033 - WARNING - Request failed with status 500 for Player 1630581, Game 22401028
# 2025-06-20 15:52:36,396 - WARNING - Request failed with status 500 for Player 1642366, Game 22401025
# 2025-06-20 15:52:36,589 - WARNING - Request failed with status 500 for Player 1642366, Game 22401025
# 2025-06-20 15:52:36,750 - WARNING - Request failed with status 500 for Player 1642366, Game 22401025
# 2025-06-20 15:52:37,374 - WARNING - Request failed with status 500 for Player 1629008, Game 22401035
# 2025-06-20 15:52:37,605 - WARNING - Request failed with status 500 for Player 1629008, Game 22401035
# 2025-06-20 15:52:37,763 - WARNING - Request failed with status 500 for Player 1629008, Game 22401035
# 2025-06-20 15:52:39,480 - WARNING - Request failed with status 500 for Player 201935, Game 22401036
# 2025-06-20 15:52:39,684 - WARNING - Request failed with status 500 for Player 201935, Game 22401036
# 2025-06-20 15:52:39,828 - WARNING - Request failed with status 500 for Player 201935, Game 22401036
# 2025-06-20 15:52:41,159 - WARNING - Request failed with status 500 for Player 1630202, Game 22401034
# 2025-06-20 15:52:41,343 - WARNING - Request failed with status 500 for Player 1630202, Game 22401034
# 2025-06-20 15:52:41,559 - WARNING - Request failed with status 500 for Player 1630202, Game 22401034
# 2025-06-20 15:52:42,498 - WARNING - Request failed with status 500 for Player 1629130, Game 22401032
# 2025-06-20 15:52:42,793 - WARNING - Request failed with status 500 for Player 1629130, Game 22401032
# 2025-06-20 15:52:43,064 - WARNING - Request failed with status 500 for Player 1629130, Game 22401032
# 2025-06-20 15:52:48,820 - WARNING - Request failed with status 500 for Player 1630288, Game 22401031
# 2025-06-20 15:52:49,088 - WARNING - Request failed with status 500 for Player 1630288, Game 22401031
# 2025-06-20 15:52:49,341 - WARNING - Request failed with status 500 for Player 1630288, Game 22401031
# 2025-06-20 15:52:50,131 - WARNING - Request failed with status 500 for Player 1642348, Game 22401031
# 2025-06-20 15:52:50,361 - WARNING - Request failed with status 500 for Player 1642348, Game 22401031
# 2025-06-20 15:52:50,551 - WARNING - Request failed with status 500 for Player 1642348, Game 22401031
# 2025-06-20 15:52:52,267 - WARNING - Request failed with status 500 for Player 1631255, Game 22401029
# 2025-06-20 15:52:52,451 - WARNING - Request failed with status 500 for Player 1631255, Game 22401029
# 2025-06-20 15:52:52,596 - WARNING - Request failed with status 500 for Player 1631255, Game 22401029
# 2025-06-20 15:52:53,274 - WARNING - Request failed with status 500 for Player 202699, Game 22401029
# 2025-06-20 15:52:53,439 - WARNING - Request failed with status 500 for Player 202699, Game 22401029
# 2025-06-20 15:52:53,611 - WARNING - Request failed with status 500 for Player 202699, Game 22401029
# 2025-06-20 15:52:54,558 - WARNING - Request failed with status 500 for Player 1629628, Game 22401033
# 2025-06-20 15:52:54,715 - WARNING - Request failed with status 500 for Player 1629628, Game 22401033
# 2025-06-20 15:52:54,861 - WARNING - Request failed with status 500 for Player 1629628, Game 22401033
# 2025-06-20 15:52:55,794 - WARNING - Request failed with status 500 for Player 1642268, Game 22401030
# 2025-06-20 15:52:55,957 - WARNING - Request failed with status 500 for Player 1642268, Game 22401030
# 2025-06-20 15:52:56,161 - WARNING - Request failed with status 500 for Player 1642268, Game 22401030
# 2025-06-20 15:52:58,179 - WARNING - Request failed with status 500 for Player 1629614, Game 22401037
# 2025-06-20 15:52:58,345 - WARNING - Request failed with status 500 for Player 1629614, Game 22401037
# 2025-06-20 15:52:58,576 - WARNING - Request failed with status 500 for Player 1629614, Game 22401037
# 2025-06-20 15:53:04,301 - WARNING - Request failed with status 500 for Player 1629643, Game 22401041
# 2025-06-20 15:53:04,450 - WARNING - Request failed with status 500 for Player 1629643, Game 22401041
# 2025-06-20 15:53:04,634 - WARNING - Request failed with status 500 for Player 1629643, Game 22401041
# 2025-06-20 15:53:05,430 - WARNING - Request failed with status 500 for Player 1630631, Game 22401041
# 2025-06-20 15:53:05,583 - WARNING - Request failed with status 500 for Player 1630631, Game 22401041
# 2025-06-20 15:53:05,808 - WARNING - Request failed with status 500 for Player 1630631, Game 22401041
# 2025-06-20 15:53:06,557 - WARNING - Request failed with status 500 for Player 1642348, Game 22401041
# 2025-06-20 15:53:06,748 - WARNING - Request failed with status 500 for Player 1642348, Game 22401041
# 2025-06-20 15:53:06,908 - WARNING - Request failed with status 500 for Player 1642348, Game 22401041
# 2025-06-20 15:53:07,695 - WARNING - Request failed with status 500 for Player 1630532, Game 22401038
# 2025-06-20 15:53:07,877 - WARNING - Request failed with status 500 for Player 1630532, Game 22401038
# 2025-06-20 15:53:08,026 - WARNING - Request failed with status 500 for Player 1630532, Game 22401038
# 2025-06-20 15:53:09,487 - WARNING - Request failed with status 500 for Player 1630533, Game 22401040
# 2025-06-20 15:53:09,739 - WARNING - Request failed with status 500 for Player 1630533, Game 22401040
# 2025-06-20 15:53:09,890 - WARNING - Request failed with status 500 for Player 1630533, Game 22401040
# 2025-06-20 15:53:12,328 - WARNING - Request failed with status 500 for Player 201942, Game 22401044
# 2025-06-20 15:53:12,549 - WARNING - Request failed with status 500 for Player 201942, Game 22401044
# 2025-06-20 15:53:12,703 - WARNING - Request failed with status 500 for Player 201942, Game 22401044
# 2025-06-20 15:53:16,750 - WARNING - Request failed with status 500 for Player 202696, Game 22401042
# 2025-06-20 15:53:16,924 - WARNING - Request failed with status 500 for Player 202696, Game 22401042
# 2025-06-20 15:53:17,084 - WARNING - Request failed with status 500 for Player 202696, Game 22401042
# 2025-06-20 15:53:19,760 - WARNING - Request failed with status 500 for Player 1629027, Game 22401049
# 2025-06-20 15:53:20,031 - WARNING - Request failed with status 500 for Player 1629027, Game 22401049
# 2025-06-20 15:53:20,183 - WARNING - Request failed with status 500 for Player 1629027, Game 22401049
# 2025-06-20 15:53:21,784 - WARNING - Request failed with status 500 for Player 1628392, Game 22401052
# 2025-06-20 15:53:22,004 - WARNING - Request failed with status 500 for Player 1628392, Game 22401052
# 2025-06-20 15:53:22,163 - WARNING - Request failed with status 500 for Player 1628392, Game 22401052
# 2025-06-20 15:53:22,167 - INFO - Processing 100/644: Player Keon Ellis (1631165) in Game 22401052 - 2025
# 2025-06-20 15:53:23,001 - WARNING - Request failed with status 500 for Player 1631165, Game 22401052
# 2025-06-20 15:53:23,162 - WARNING - Request failed with status 500 for Player 1631165, Game 22401052
# 2025-06-20 15:53:23,331 - WARNING - Request failed with status 500 for Player 1631165, Game 22401052
# 2025-06-20 15:53:26,601 - WARNING - Request failed with status 500 for Player 203952, Game 22401047
# 2025-06-20 15:53:26,747 - WARNING - Request failed with status 500 for Player 203952, Game 22401047
# 2025-06-20 15:53:26,893 - WARNING - Request failed with status 500 for Player 203952, Game 22401047
# 2025-06-20 15:53:28,289 - WARNING - Request failed with status 500 for Player 1629014, Game 22401051
# 2025-06-20 15:53:28,571 - WARNING - Request failed with status 500 for Player 1629014, Game 22401051
# 2025-06-20 15:53:28,739 - WARNING - Request failed with status 500 for Player 1629014, Game 22401051
# 2025-06-20 15:53:29,518 - WARNING - Request failed with status 500 for Player 1629622, Game 22401051
# 2025-06-20 15:53:30,007 - WARNING - Request failed with status 500 for Player 1629622, Game 22401051
# 2025-06-20 15:53:30,310 - WARNING - Request failed with status 500 for Player 1629622, Game 22401051
# 2025-06-20 15:53:32,027 - WARNING - Request failed with status 500 for Player 1631094, Game 22401045
# 2025-06-20 15:53:32,178 - WARNING - Request failed with status 500 for Player 1631094, Game 22401045
# 2025-06-20 15:53:32,327 - WARNING - Request failed with status 500 for Player 1631094, Game 22401045
# 2025-06-20 15:53:33,010 - WARNING - Request failed with status 500 for Player 1630539, Game 22401048
# 2025-06-20 15:53:33,172 - WARNING - Request failed with status 500 for Player 1630539, Game 22401048
# 2025-06-20 15:53:33,336 - WARNING - Request failed with status 500 for Player 1630539, Game 22401048
# 2025-06-20 15:53:34,051 - WARNING - Request failed with status 500 for Player 1628969, Game 22401048
# 2025-06-20 15:53:34,236 - WARNING - Request failed with status 500 for Player 1628969, Game 22401048
# 2025-06-20 15:53:34,384 - WARNING - Request failed with status 500 for Player 1628969, Game 22401048
# 2025-06-20 15:53:35,073 - WARNING - Request failed with status 500 for Player 1641709, Game 22401046
# 2025-06-20 15:53:35,227 - WARNING - Request failed with status 500 for Player 1641709, Game 22401046
# 2025-06-20 15:53:35,447 - WARNING - Request failed with status 500 for Player 1641709, Game 22401046
# 2025-06-20 15:53:37,808 - WARNING - Request failed with status 500 for Player 1630217, Game 22401050
# 2025-06-20 15:53:37,954 - WARNING - Request failed with status 500 for Player 1630217, Game 22401050
# 2025-06-20 15:53:38,126 - WARNING - Request failed with status 500 for Player 1630217, Game 22401050
# 2025-06-20 15:53:39,684 - WARNING - Request failed with status 500 for Player 1631117, Game 22401050
# 2025-06-20 15:53:39,833 - WARNING - Request failed with status 500 for Player 1631117, Game 22401050
# 2025-06-20 15:53:40,241 - WARNING - Request failed with status 500 for Player 1631117, Game 22401050
# 2025-06-20 15:53:41,135 - WARNING - Request failed with status 500 for Player 1630533, Game 22401054
# 2025-06-20 15:53:41,289 - WARNING - Request failed with status 500 for Player 1630533, Game 22401054
# 2025-06-20 15:53:41,446 - WARNING - Request failed with status 500 for Player 1630533, Game 22401054
# 2025-06-20 15:53:42,114 - WARNING - Request failed with status 500 for Player 203999, Game 22401057
# 2025-06-20 15:53:42,266 - WARNING - Request failed with status 500 for Player 203999, Game 22401057
# 2025-06-20 15:53:42,554 - WARNING - Request failed with status 500 for Player 203999, Game 22401057
# 2025-06-20 15:53:44,266 - WARNING - Request failed with status 500 for Player 1627752, Game 22401057
# 2025-06-20 15:53:44,459 - WARNING - Request failed with status 500 for Player 1627752, Game 22401057
# 2025-06-20 15:53:44,606 - WARNING - Request failed with status 500 for Player 1627752, Game 22401057
# 2025-06-20 15:53:45,296 - WARNING - Request failed with status 500 for Player 1629614, Game 22401055
# 2025-06-20 15:53:45,495 - WARNING - Request failed with status 500 for Player 1629614, Game 22401055
# 2025-06-20 15:53:45,661 - WARNING - Request failed with status 500 for Player 1629614, Game 22401055
# 2025-06-20 15:53:47,073 - WARNING - Request failed with status 500 for Player 1626167, Game 22401055
# 2025-06-20 15:53:47,228 - WARNING - Request failed with status 500 for Player 1626167, Game 22401055
# 2025-06-20 15:53:47,383 - WARNING - Request failed with status 500 for Player 1626167, Game 22401055
# 2025-06-20 15:53:50,839 - WARNING - Request failed with status 500 for Player 201142, Game 22401058
# 2025-06-20 15:53:51,031 - WARNING - Request failed with status 500 for Player 201142, Game 22401058
# 2025-06-20 15:53:51,196 - WARNING - Request failed with status 500 for Player 201142, Game 22401058
# 2025-06-20 15:53:54,610 - WARNING - Request failed with status 500 for Player 1642346, Game 22401058
# 2025-06-20 15:53:54,817 - WARNING - Request failed with status 500 for Player 1642346, Game 22401058
# 2025-06-20 15:53:54,977 - WARNING - Request failed with status 500 for Player 1642346, Game 22401058
# 2025-06-20 15:53:56,523 - WARNING - Request failed with status 500 for Player 1627826, Game 22401056
# 2025-06-20 15:53:56,726 - WARNING - Request failed with status 500 for Player 1627826, Game 22401056
# 2025-06-20 15:53:56,883 - WARNING - Request failed with status 500 for Player 1627826, Game 22401056
# 2025-06-20 15:53:57,646 - WARNING - Request failed with status 500 for Player 1626157, Game 22401056
# 2025-06-20 15:53:57,908 - WARNING - Request failed with status 500 for Player 1626157, Game 22401056
# 2025-06-20 15:53:59,091 - WARNING - Request failed with status 500 for Player 1626157, Game 22401056
# 2025-06-20 15:54:01,233 - WARNING - Request failed with status 500 for Player 1642267, Game 22401061
# 2025-06-20 15:54:01,379 - WARNING - Request failed with status 500 for Player 1642267, Game 22401061
# 2025-06-20 15:54:01,520 - WARNING - Request failed with status 500 for Player 1642267, Game 22401061
# 2025-06-20 15:54:04,322 - WARNING - Request failed with status 500 for Player 1630578, Game 22401065
# 2025-06-20 15:54:04,496 - WARNING - Request failed with status 500 for Player 1630578, Game 22401065
# 2025-06-20 15:54:04,644 - WARNING - Request failed with status 500 for Player 1630578, Game 22401065
# 2025-06-20 15:54:05,517 - WARNING - Request failed with status 500 for Player 1642271, Game 22401065
# 2025-06-20 15:54:05,903 - WARNING - Request failed with status 500 for Player 1642271, Game 22401065
# 2025-06-20 15:54:06,344 - WARNING - Request failed with status 500 for Player 1642271, Game 22401065
# 2025-06-20 15:54:08,838 - WARNING - Request failed with status 500 for Player 1628983, Game 22401064
# 2025-06-20 15:54:09,160 - WARNING - Request failed with status 500 for Player 1628983, Game 22401064
# 2025-06-20 15:54:09,497 - WARNING - Request failed with status 500 for Player 1628983, Game 22401064
# 2025-06-20 15:54:10,270 - WARNING - Request failed with status 500 for Player 1642270, Game 22401066
# 2025-06-20 15:54:10,553 - WARNING - Request failed with status 500 for Player 1642270, Game 22401066
# 2025-06-20 15:54:10,911 - WARNING - Request failed with status 500 for Player 1642270, Game 22401066
# 2025-06-20 15:54:12,552 - WARNING - Request failed with status 500 for Player 1631099, Game 22401066
# 2025-06-20 15:54:12,703 - WARNING - Request failed with status 500 for Player 1631099, Game 22401066
# 2025-06-20 15:54:12,843 - WARNING - Request failed with status 500 for Player 1631099, Game 22401066
# 2025-06-20 15:54:17,860 - WARNING - Request failed with status 500 for Player 203076, Game 22401060
# 2025-06-20 15:54:18,050 - WARNING - Request failed with status 500 for Player 203076, Game 22401060
# 2025-06-20 15:54:18,197 - WARNING - Request failed with status 500 for Player 203076, Game 22401060
# 2025-06-20 15:54:18,861 - WARNING - Request failed with status 500 for Player 203484, Game 22401060
# 2025-06-20 15:54:19,067 - WARNING - Request failed with status 500 for Player 203484, Game 22401060
# 2025-06-20 15:54:19,207 - WARNING - Request failed with status 500 for Player 203484, Game 22401060
# 2025-06-20 15:54:19,909 - WARNING - Request failed with status 500 for Player 1641824, Game 22401063
# 2025-06-20 15:54:20,164 - WARNING - Request failed with status 500 for Player 1641824, Game 22401063
# 2025-06-20 15:54:20,312 - WARNING - Request failed with status 500 for Player 1641824, Game 22401063
# 2025-06-20 15:54:21,079 - WARNING - Request failed with status 500 for Player 1629636, Game 22401059
# 2025-06-20 15:54:21,293 - WARNING - Request failed with status 500 for Player 1629636, Game 22401059
# 2025-06-20 15:54:21,435 - WARNING - Request failed with status 500 for Player 1629636, Game 22401059
# 2025-06-20 15:54:22,110 - WARNING - Request failed with status 500 for Player 1629610, Game 22401069
# 2025-06-20 15:54:22,331 - WARNING - Request failed with status 500 for Player 1629610, Game 22401069
# 2025-06-20 15:54:22,485 - WARNING - Request failed with status 500 for Player 1629610, Game 22401069
# 2025-06-20 15:54:24,113 - WARNING - Request failed with status 500 for Player 203507, Game 22401070
# 2025-06-20 15:54:24,381 - WARNING - Request failed with status 500 for Player 203507, Game 22401070
# 2025-06-20 15:54:24,542 - WARNING - Request failed with status 500 for Player 203507, Game 22401070
# 2025-06-20 15:54:25,272 - WARNING - Request failed with status 500 for Player 1628404, Game 22401070
# 2025-06-20 15:54:27,777 - WARNING - Request failed with status 500 for Player 1628404, Game 22401070
# 2025-06-20 15:54:27,929 - WARNING - Request failed with status 500 for Player 1628404, Game 22401070
# 2025-06-20 15:54:27,933 - INFO - Processing 150/644: Player Karl-Anthony Towns (1626157) in Game 22401070 - 2025
# 2025-06-20 15:54:28,904 - WARNING - Request failed with status 500 for Player 1626157, Game 22401070
# 2025-06-20 15:54:29,195 - WARNING - Request failed with status 500 for Player 1626157, Game 22401070
# 2025-06-20 15:54:29,342 - WARNING - Request failed with status 500 for Player 1626157, Game 22401070
# 2025-06-20 15:54:32,499 - WARNING - Request failed with status 500 for Player 1642271, Game 22401073
# 2025-06-20 15:54:32,723 - WARNING - Request failed with status 500 for Player 1642271, Game 22401073
# 2025-06-20 15:54:32,880 - WARNING - Request failed with status 500 for Player 1642271, Game 22401073
# 2025-06-20 15:54:33,666 - WARNING - Request failed with status 500 for Player 1631131, Game 22401073
# 2025-06-20 15:54:33,825 - WARNING - Request failed with status 500 for Player 1631131, Game 22401073
# 2025-06-20 15:54:33,972 - WARNING - Request failed with status 500 for Player 1631131, Game 22401073
# 2025-06-20 15:54:35,411 - WARNING - Request failed with status 500 for Player 1630553, Game 22401068
# 2025-06-20 15:54:35,561 - WARNING - Request failed with status 500 for Player 1630553, Game 22401068
# 2025-06-20 15:54:35,713 - WARNING - Request failed with status 500 for Player 1630553, Game 22401068
# 2025-06-20 15:54:37,118 - WARNING - Request failed with status 500 for Player 203482, Game 22401072
# 2025-06-20 15:54:37,445 - WARNING - Request failed with status 500 for Player 203482, Game 22401072
# 2025-06-20 15:54:37,601 - WARNING - Request failed with status 500 for Player 203482, Game 22401072
# 2025-06-20 15:54:39,683 - WARNING - Request failed with status 500 for Player 1641709, Game 22401067
# 2025-06-20 15:54:39,825 - WARNING - Request failed with status 500 for Player 1641709, Game 22401067
# 2025-06-20 15:54:39,966 - WARNING - Request failed with status 500 for Player 1641709, Game 22401067
# 2025-06-20 15:54:42,295 - WARNING - Request failed with status 500 for Player 1627736, Game 22401067
# 2025-06-20 15:54:42,445 - WARNING - Request failed with status 500 for Player 1627736, Game 22401067
# 2025-06-20 15:54:42,604 - WARNING - Request failed with status 500 for Player 1627736, Game 22401067
# 2025-06-20 15:54:44,212 - WARNING - Request failed with status 500 for Player 1641730, Game 22401075
# 2025-06-20 15:54:44,355 - WARNING - Request failed with status 500 for Player 1641730, Game 22401075
# 2025-06-20 15:54:44,499 - WARNING - Request failed with status 500 for Player 1641730, Game 22401075
# 2025-06-20 15:54:45,149 - WARNING - Request failed with status 500 for Player 1628392, Game 22401079
# 2025-06-20 15:54:45,326 - WARNING - Request failed with status 500 for Player 1628392, Game 22401079
# 2025-06-20 15:54:45,488 - WARNING - Request failed with status 500 for Player 1628392, Game 22401079
# 2025-06-20 15:54:48,500 - WARNING - Request failed with status 500 for Player 1642276, Game 22401076
# 2025-06-20 15:54:48,727 - WARNING - Request failed with status 500 for Player 1642276, Game 22401076
# 2025-06-20 15:54:48,886 - WARNING - Request failed with status 500 for Player 1642276, Game 22401076
# 2025-06-20 15:54:50,296 - WARNING - Request failed with status 500 for Player 1629656, Game 22401076
# 2025-06-20 15:54:50,453 - WARNING - Request failed with status 500 for Player 1629656, Game 22401076
# 2025-06-20 15:54:50,605 - WARNING - Request failed with status 500 for Player 1629656, Game 22401076
# 2025-06-20 15:54:54,664 - WARNING - Request failed with status 500 for Player 1627734, Game 22401074
# 2025-06-20 15:54:54,881 - WARNING - Request failed with status 500 for Player 1627734, Game 22401074
# 2025-06-20 15:54:55,032 - WARNING - Request failed with status 500 for Player 1627734, Game 22401074
# 2025-06-20 15:54:58,178 - WARNING - Request failed with status 500 for Player 1630581, Game 22401077
# 2025-06-20 15:54:58,363 - WARNING - Request failed with status 500 for Player 1630581, Game 22401077
# 2025-06-20 15:54:58,517 - WARNING - Request failed with status 500 for Player 1630581, Game 22401077
# 2025-06-20 15:54:59,133 - WARNING - Request failed with status 500 for Player 1631110, Game 22401080
# 2025-06-20 15:54:59,288 - WARNING - Request failed with status 500 for Player 1631110, Game 22401080
# 2025-06-20 15:54:59,441 - WARNING - Request failed with status 500 for Player 1631110, Game 22401080
# 2025-06-20 15:55:01,903 - WARNING - Request failed with status 500 for Player 1629628, Game 22401087
# 2025-06-20 15:55:02,051 - WARNING - Request failed with status 500 for Player 1629628, Game 22401087
# 2025-06-20 15:55:02,233 - WARNING - Request failed with status 500 for Player 1629628, Game 22401087
# 2025-06-20 15:55:03,007 - WARNING - Request failed with status 500 for Player 1628415, Game 22401088
# 2025-06-20 15:55:03,173 - WARNING - Request failed with status 500 for Player 1628415, Game 22401088
# 2025-06-20 15:55:03,325 - WARNING - Request failed with status 500 for Player 1628415, Game 22401088
# 2025-06-20 15:55:05,694 - WARNING - Request failed with status 500 for Player 1630208, Game 22401088
# 2025-06-20 15:55:05,841 - WARNING - Request failed with status 500 for Player 1630208, Game 22401088
# 2025-06-20 15:55:06,037 - WARNING - Request failed with status 500 for Player 1630208, Game 22401088
# 2025-06-20 15:55:06,673 - WARNING - Request failed with status 500 for Player 1629636, Game 22401081
# 2025-06-20 15:55:06,859 - WARNING - Request failed with status 500 for Player 1629636, Game 22401081
# 2025-06-20 15:55:07,024 - WARNING - Request failed with status 500 for Player 1629636, Game 22401081
# 2025-06-20 15:55:07,676 - WARNING - Request failed with status 500 for Player 1628386, Game 22401081
# 2025-06-20 15:55:07,832 - WARNING - Request failed with status 500 for Player 1628386, Game 22401081
# 2025-06-20 15:55:07,999 - WARNING - Request failed with status 500 for Player 1628386, Game 22401081
# 2025-06-20 15:55:08,741 - WARNING - Request failed with status 500 for Player 1626181, Game 22401081
# 2025-06-20 15:55:08,897 - WARNING - Request failed with status 500 for Player 1626181, Game 22401081
# 2025-06-20 15:55:09,066 - WARNING - Request failed with status 500 for Player 1626181, Game 22401081
# 2025-06-20 15:55:11,226 - WARNING - Request failed with status 500 for Player 1642258, Game 22401083
# 2025-06-20 15:55:11,425 - WARNING - Request failed with status 500 for Player 1642258, Game 22401083
# 2025-06-20 15:55:11,580 - WARNING - Request failed with status 500 for Player 1642258, Game 22401083
# 2025-06-20 15:55:13,645 - WARNING - Request failed with status 500 for Player 1628384, Game 22401082
# 2025-06-20 15:55:13,791 - WARNING - Request failed with status 500 for Player 1628384, Game 22401082
# 2025-06-20 15:55:13,943 - WARNING - Request failed with status 500 for Player 1628384, Game 22401082
# 2025-06-20 15:55:19,268 - WARNING - Request failed with status 500 for Player 201144, Game 22401084
# 2025-06-20 15:55:19,410 - WARNING - Request failed with status 500 for Player 201144, Game 22401084
# 2025-06-20 15:55:19,597 - WARNING - Request failed with status 500 for Player 201144, Game 22401084
# 2025-06-20 15:55:20,982 - WARNING - Request failed with status 500 for Player 203482, Game 22401085
# 2025-06-20 15:55:21,163 - WARNING - Request failed with status 500 for Player 203482, Game 22401085
# 2025-06-20 15:55:21,303 - WARNING - Request failed with status 500 for Player 203482, Game 22401085
# 2025-06-20 15:55:22,058 - WARNING - Request failed with status 500 for Player 1631110, Game 22401086
# 2025-06-20 15:55:22,205 - WARNING - Request failed with status 500 for Player 1631110, Game 22401086
# 2025-06-20 15:55:22,451 - WARNING - Request failed with status 500 for Player 1631110, Game 22401086
# 2025-06-20 15:55:23,264 - WARNING - Request failed with status 500 for Player 1642358, Game 22401092
# 2025-06-20 15:55:23,574 - WARNING - Request failed with status 500 for Player 1642358, Game 22401092
# 2025-06-20 15:55:23,721 - WARNING - Request failed with status 500 for Player 1642358, Game 22401092
# 2025-06-20 15:55:23,724 - INFO - Processing 200/644: Player Isaiah Stevens (1641815) in Game 22401092 - 2025
# 2025-06-20 15:55:26,756 - WARNING - Request failed with status 500 for Player 201942, Game 22401090
# 2025-06-20 15:55:26,908 - WARNING - Request failed with status 500 for Player 201942, Game 22401090
# 2025-06-20 15:55:27,102 - WARNING - Request failed with status 500 for Player 201942, Game 22401090
# 2025-06-20 15:55:28,566 - WARNING - Request failed with status 500 for Player 1628401, Game 22401093
# 2025-06-20 15:55:28,725 - WARNING - Request failed with status 500 for Player 1628401, Game 22401093
# 2025-06-20 15:55:28,955 - WARNING - Request failed with status 500 for Player 1628401, Game 22401093
# 2025-06-20 15:55:29,784 - WARNING - Request failed with status 500 for Player 1629630, Game 22401093
# 2025-06-20 15:55:29,934 - WARNING - Request failed with status 500 for Player 1629630, Game 22401093
# 2025-06-20 15:55:30,116 - WARNING - Request failed with status 500 for Player 1629630, Game 22401093
# 2025-06-20 15:55:32,377 - WARNING - Request failed with status 500 for Player 1641824, Game 22401094
# 2025-06-20 15:55:32,696 - WARNING - Request failed with status 500 for Player 1641824, Game 22401094
# 2025-06-20 15:55:33,098 - WARNING - Request failed with status 500 for Player 1641824, Game 22401094
# 2025-06-20 15:55:35,774 - WARNING - Request failed with status 500 for Player 1630559, Game 22401096
# 2025-06-20 15:55:35,956 - WARNING - Request failed with status 500 for Player 1630559, Game 22401096
# 2025-06-20 15:55:36,107 - WARNING - Request failed with status 500 for Player 1630559, Game 22401096
# 2025-06-20 15:55:37,022 - WARNING - Request failed with status 500 for Player 1627739, Game 22401091
# 2025-06-20 15:55:37,172 - WARNING - Request failed with status 500 for Player 1627739, Game 22401091
# 2025-06-20 15:55:37,361 - WARNING - Request failed with status 500 for Player 1627739, Game 22401091
# 2025-06-20 15:55:38,532 - WARNING - Request failed with status 500 for Player 1629655, Game 22401095
# 2025-06-20 15:55:38,728 - WARNING - Request failed with status 500 for Player 1629655, Game 22401095
# 2025-06-20 15:55:38,927 - WARNING - Request failed with status 500 for Player 1629655, Game 22401095
# 2025-06-20 15:55:41,349 - WARNING - Request failed with status 500 for Player 1630548, Game 22401089
# 2025-06-20 15:55:41,534 - WARNING - Request failed with status 500 for Player 1630548, Game 22401089
# 2025-06-20 15:55:41,721 - WARNING - Request failed with status 500 for Player 1630548, Game 22401089
# 2025-06-20 15:55:42,497 - WARNING - Request failed with status 500 for Player 1642271, Game 22401089
# 2025-06-20 15:55:42,721 - WARNING - Request failed with status 500 for Player 1642271, Game 22401089
# 2025-06-20 15:55:42,869 - WARNING - Request failed with status 500 for Player 1642271, Game 22401089
# 2025-06-20 15:55:43,544 - WARNING - Request failed with status 500 for Player 1628970, Game 22401089
# 2025-06-20 15:55:43,735 - WARNING - Request failed with status 500 for Player 1628970, Game 22401089
# 2025-06-20 15:55:43,897 - WARNING - Request failed with status 500 for Player 1628970, Game 22401089
# 2025-06-20 15:55:45,353 - WARNING - Request failed with status 500 for Player 1641824, Game 22401099
# 2025-06-20 15:55:45,499 - WARNING - Request failed with status 500 for Player 1641824, Game 22401099
# 2025-06-20 15:55:45,710 - WARNING - Request failed with status 500 for Player 1641824, Game 22401099
# 2025-06-20 15:55:47,647 - WARNING - Request failed with status 500 for Player 202709, Game 22400988
# 2025-06-20 15:55:47,831 - WARNING - Request failed with status 500 for Player 202709, Game 22400988
# 2025-06-20 15:55:47,979 - WARNING - Request failed with status 500 for Player 202709, Game 22400988
# 2025-06-20 15:55:48,687 - WARNING - Request failed with status 500 for Player 1630532, Game 22400988
# 2025-06-20 15:55:48,846 - WARNING - Request failed with status 500 for Player 1630532, Game 22400988
# 2025-06-20 15:55:48,999 - WARNING - Request failed with status 500 for Player 1630532, Game 22400988
# 2025-06-20 15:55:52,799 - WARNING - Request failed with status 500 for Player 1642264, Game 22400988
# 2025-06-20 15:55:52,951 - WARNING - Request failed with status 500 for Player 1642264, Game 22400988
# 2025-06-20 15:55:53,116 - WARNING - Request failed with status 500 for Player 1642264, Game 22400988
# 2025-06-20 15:55:53,757 - WARNING - Request failed with status 500 for Player 1641744, Game 22401100
# 2025-06-20 15:55:53,918 - WARNING - Request failed with status 500 for Player 1641744, Game 22401100
# 2025-06-20 15:55:54,072 - WARNING - Request failed with status 500 for Player 1641744, Game 22401100
# 2025-06-20 15:55:54,776 - WARNING - Request failed with status 500 for Player 203507, Game 22401101
# 2025-06-20 15:55:55,042 - WARNING - Request failed with status 500 for Player 203507, Game 22401101
# 2025-06-20 15:55:55,236 - WARNING - Request failed with status 500 for Player 203507, Game 22401101
# 2025-06-20 15:55:55,947 - WARNING - Request failed with status 500 for Player 1630208, Game 22401101
# 2025-06-20 15:55:56,131 - WARNING - Request failed with status 500 for Player 1630208, Game 22401101
# 2025-06-20 15:55:56,407 - WARNING - Request failed with status 500 for Player 1630208, Game 22401101
# 2025-06-20 15:55:57,872 - WARNING - Request failed with status 500 for Player 1642270, Game 22401097
# 2025-06-20 15:55:58,234 - WARNING - Request failed with status 500 for Player 1642270, Game 22401097
# 2025-06-20 15:55:58,399 - WARNING - Request failed with status 500 for Player 1642270, Game 22401097
# 2025-06-20 15:56:00,109 - WARNING - Request failed with status 500 for Player 1641739, Game 22401097
# 2025-06-20 15:56:00,270 - WARNING - Request failed with status 500 for Player 1641739, Game 22401097
# 2025-06-20 15:56:00,570 - WARNING - Request failed with status 500 for Player 1641739, Game 22401097
# 2025-06-20 15:56:01,229 - WARNING - Request failed with status 500 for Player 1629027, Game 22401097
# 2025-06-20 15:56:01,387 - WARNING - Request failed with status 500 for Player 1629027, Game 22401097
# 2025-06-20 15:56:01,537 - WARNING - Request failed with status 500 for Player 1629027, Game 22401097
# 2025-06-20 15:56:04,530 - WARNING - Request failed with status 500 for Player 203897, Game 22401105
# 2025-06-20 15:56:04,738 - WARNING - Request failed with status 500 for Player 203897, Game 22401105
# 2025-06-20 15:56:04,889 - WARNING - Request failed with status 500 for Player 203897, Game 22401105
# 2025-06-20 15:56:07,146 - WARNING - Request failed with status 500 for Player 1630169, Game 22401104
# 2025-06-20 15:56:07,587 - WARNING - Request failed with status 500 for Player 1630169, Game 22401104
# 2025-06-20 15:56:09,689 - WARNING - Request failed with status 500 for Player 1630169, Game 22401104
# 2025-06-20 15:56:12,870 - WARNING - Request failed with status 500 for Player 1629652, Game 22401108
# 2025-06-20 15:56:13,031 - WARNING - Request failed with status 500 for Player 1629652, Game 22401108
# 2025-06-20 15:56:13,186 - WARNING - Request failed with status 500 for Player 1629652, Game 22401108
# 2025-06-20 15:56:13,990 - WARNING - Request failed with status 500 for Player 202692, Game 22401106
# 2025-06-20 15:56:14,190 - WARNING - Request failed with status 500 for Player 202692, Game 22401106
# 2025-06-20 15:56:14,362 - WARNING - Request failed with status 500 for Player 202692, Game 22401106
# 2025-06-20 15:56:18,740 - WARNING - Request failed with status 500 for Player 202691, Game 22401109
# 2025-06-20 15:56:18,910 - WARNING - Request failed with status 500 for Player 202691, Game 22401109
# 2025-06-20 15:56:19,053 - WARNING - Request failed with status 500 for Player 202691, Game 22401109
# 2025-06-20 15:56:19,737 - WARNING - Request failed with status 500 for Player 1630168, Game 22401109
# 2025-06-20 15:56:19,874 - WARNING - Request failed with status 500 for Player 1630168, Game 22401109
# 2025-06-20 15:56:20,010 - WARNING - Request failed with status 500 for Player 1630168, Game 22401109
# 2025-06-20 15:56:20,586 - WARNING - Request failed with status 500 for Player 1626153, Game 22401103
# 2025-06-20 15:56:20,721 - WARNING - Request failed with status 500 for Player 1626153, Game 22401103
# 2025-06-20 15:56:20,864 - WARNING - Request failed with status 500 for Player 1626153, Game 22401103
# 2025-06-20 15:56:23,623 - WARNING - Request failed with status 500 for Player 1627739, Game 22401111
# 2025-06-20 15:56:23,808 - WARNING - Request failed with status 500 for Player 1627739, Game 22401111
# 2025-06-20 15:56:23,964 - WARNING - Request failed with status 500 for Player 1627739, Game 22401111
# 2025-06-20 15:56:24,814 - INFO - Processing 250/644: Player Hunter Tyson (1641816) in Game 22401110 - 2025
# 2025-06-20 15:56:25,460 - WARNING - Request failed with status 500 for Player 1641816, Game 22401110
# 2025-06-20 15:56:25,607 - WARNING - Request failed with status 500 for Player 1641816, Game 22401110
# ...
# 2025-06-20 16:02:24,466 - WARNING - Request failed with status 500 for Player 1627750, Game 42400222
# 2025-06-20 16:02:24,678 - WARNING - Request failed with status 500 for Player 1627750, Game 42400222
# 2025-06-20 16:02:26,228 - WARNING - Request failed with status 500 for Player 201143, Game 42400212
# 2025-06-20 16:02:26,376 - WARNING - Request failed with status 500 for Player 201143, Game 42400212
# 2025-06-20 16:02:26,555 - WARNING - Request failed with status 500 for Player 201143, Game 42400212
# 2025-06-20 16:02:26,560 - INFO - Processing 550/644: Player Jalen Brunson (1628973) in Game 42400212 - 2025
# 2025-06-20 16:02:27,501 - WARNING - Request failed with status 500 for Player 1628973, Game 42400212
# 2025-06-20 16:02:27,694 - WARNING - Request failed with status 500 for Player 1628973, Game 42400212
# 2025-06-20 16:02:27,838 - WARNING - Request failed with status 500 for Player 1628973, Game 42400212
# 2025-06-20 16:02:30,327 - WARNING - Request failed with status 500 for Player 1630162, Game 42400232
# 2025-06-20 16:02:30,530 - WARNING - Request failed with status 500 for Player 1630162, Game 42400232
# 2025-06-20 16:02:30,683 - WARNING - Request failed with status 500 for Player 1630162, Game 42400232
# 2025-06-20 16:02:34,008 - WARNING - Request failed with status 500 for Player 1642366, Game 42400232
# 2025-06-20 16:02:34,192 - WARNING - Request failed with status 500 for Player 1642366, Game 42400232
# 2025-06-20 16:02:34,337 - WARNING - Request failed with status 500 for Player 1642366, Game 42400232
# 2025-06-20 16:02:35,788 - WARNING - Request failed with status 500 for Player 1627750, Game 42400223
# 2025-06-20 16:02:35,935 - WARNING - Request failed with status 500 for Player 1627750, Game 42400223
# 2025-06-20 16:02:36,088 - WARNING - Request failed with status 500 for Player 1627750, Game 42400223
# 2025-06-20 16:02:36,827 - WARNING - Request failed with status 500 for Player 1629614, Game 42400203
# 2025-06-20 16:02:36,974 - WARNING - Request failed with status 500 for Player 1629614, Game 42400203
# 2025-06-20 16:02:37,129 - WARNING - Request failed with status 500 for Player 1629614, Game 42400203
# 2025-06-20 16:02:40,668 - WARNING - Request failed with status 500 for Player 1628401, Game 42400213
# 2025-06-20 16:02:40,821 - WARNING - Request failed with status 500 for Player 1628401, Game 42400213
# 2025-06-20 16:02:40,972 - WARNING - Request failed with status 500 for Player 1628401, Game 42400213
# 2025-06-20 16:02:44,313 - WARNING - Request failed with status 500 for Player 1626157, Game 42400213
# 2025-06-20 16:02:44,468 - WARNING - Request failed with status 500 for Player 1626157, Game 42400213
# 2025-06-20 16:02:44,651 - WARNING - Request failed with status 500 for Player 1626157, Game 42400213
# 2025-06-20 16:02:46,160 - WARNING - Request failed with status 500 for Player 203110, Game 42400233
# 2025-06-20 16:02:46,309 - WARNING - Request failed with status 500 for Player 203110, Game 42400233
# 2025-06-20 16:02:46,509 - WARNING - Request failed with status 500 for Player 203110, Game 42400233
# 2025-06-20 16:02:47,305 - WARNING - Request failed with status 500 for Player 1630183, Game 42400233
# 2025-06-20 16:02:47,454 - WARNING - Request failed with status 500 for Player 1630183, Game 42400233
# 2025-06-20 16:02:47,610 - WARNING - Request failed with status 500 for Player 1630183, Game 42400233
# 2025-06-20 16:02:48,450 - WARNING - Request failed with status 500 for Player 1629652, Game 42400224
# 2025-06-20 16:02:48,716 - WARNING - Request failed with status 500 for Player 1629652, Game 42400224
# 2025-06-20 16:02:48,869 - WARNING - Request failed with status 500 for Player 1629652, Game 42400224
# 2025-06-20 16:02:52,027 - WARNING - Request failed with status 500 for Player 1627759, Game 42400214
# 2025-06-20 16:02:52,182 - WARNING - Request failed with status 500 for Player 1627759, Game 42400214
# 2025-06-20 16:02:52,332 - WARNING - Request failed with status 500 for Player 1627759, Game 42400214
# 2025-06-20 16:02:54,877 - WARNING - Request failed with status 500 for Player 1641764, Game 42400234
# 2025-06-20 16:02:55,095 - WARNING - Request failed with status 500 for Player 1641764, Game 42400234
# 2025-06-20 16:02:55,248 - WARNING - Request failed with status 500 for Player 1641764, Game 42400234
# 2025-06-20 16:02:58,597 - WARNING - Request failed with status 500 for Player 1631096, Game 42400226
# 2025-06-20 16:02:58,791 - WARNING - Request failed with status 500 for Player 1631096, Game 42400226
# 2025-06-20 16:02:58,946 - WARNING - Request failed with status 500 for Player 1631096, Game 42400226
# 2025-06-20 16:03:01,728 - WARNING - Request failed with status 500 for Player 1631096, Game 42400225
# 2025-06-20 16:03:01,879 - WARNING - Request failed with status 500 for Player 1631096, Game 42400225
# 2025-06-20 16:03:02,077 - WARNING - Request failed with status 500 for Player 1631096, Game 42400225
# 2025-06-20 16:03:02,830 - WARNING - Request failed with status 500 for Player 1629008, Game 42400225
# 2025-06-20 16:03:03,035 - WARNING - Request failed with status 500 for Player 1629008, Game 42400225
# 2025-06-20 16:03:03,207 - WARNING - Request failed with status 500 for Player 1629008, Game 42400225
# 2025-06-20 16:03:03,975 - WARNING - Request failed with status 500 for Player 1629636, Game 42400205
# 2025-06-20 16:03:04,130 - WARNING - Request failed with status 500 for Player 1629636, Game 42400205
# 2025-06-20 16:03:04,284 - WARNING - Request failed with status 500 for Player 1629636, Game 42400205
# 2025-06-20 16:03:07,007 - WARNING - Request failed with status 500 for Player 1628378, Game 42400205
# 2025-06-20 16:03:07,159 - WARNING - Request failed with status 500 for Player 1628378, Game 42400205
# 2025-06-20 16:03:07,358 - WARNING - Request failed with status 500 for Player 1628378, Game 42400205
# 2025-06-20 16:03:11,890 - WARNING - Request failed with status 500 for Player 1628384, Game 42400215
# 2025-06-20 16:03:13,655 - WARNING - Request failed with status 500 for Player 1628384, Game 42400215
# 2025-06-20 16:03:13,841 - WARNING - Request failed with status 500 for Player 1628384, Game 42400215
# 2025-06-20 16:03:14,635 - WARNING - Request failed with status 500 for Player 201144, Game 42400235
# 2025-06-20 16:03:14,850 - WARNING - Request failed with status 500 for Player 201144, Game 42400235
# 2025-06-20 16:03:14,996 - WARNING - Request failed with status 500 for Player 201144, Game 42400235
# 2025-06-20 16:03:15,670 - WARNING - Request failed with status 500 for Player 1628392, Game 42400227
# 2025-06-20 16:03:15,910 - WARNING - Request failed with status 500 for Player 1628392, Game 42400227
# 2025-06-20 16:03:16,105 - WARNING - Request failed with status 500 for Player 1628392, Game 42400227
# 2025-06-20 16:03:19,036 - WARNING - Request failed with status 500 for Player 1628969, Game 42400216
# 2025-06-20 16:03:19,200 - WARNING - Request failed with status 500 for Player 1628969, Game 42400216
# 2025-06-20 16:03:19,391 - WARNING - Request failed with status 500 for Player 1628969, Game 42400216
# 2025-06-20 16:03:20,907 - WARNING - Request failed with status 500 for Player 1631096, Game 42400311
# 2025-06-20 16:03:21,052 - WARNING - Request failed with status 500 for Player 1631096, Game 42400311
# 2025-06-20 16:03:21,233 - WARNING - Request failed with status 500 for Player 1631096, Game 42400311
# 2025-06-20 16:03:25,561 - WARNING - Request failed with status 500 for Player 1628384, Game 42400301
# 2025-06-20 16:03:25,820 - WARNING - Request failed with status 500 for Player 1628384, Game 42400301
# 2025-06-20 16:03:25,972 - WARNING - Request failed with status 500 for Player 1628384, Game 42400301
# 2025-06-20 16:03:25,976 - INFO - Processing 600/644: Player Anthony Edwards (1630162) in Game 42400312 - 2025
# 2025-06-20 16:03:31,531 - WARNING - Request failed with status 500 for Player 1628392, Game 42400312
# 2025-06-20 16:03:31,674 - WARNING - Request failed with status 500 for Player 1628392, Game 42400312
# 2025-06-20 16:03:31,910 - WARNING - Request failed with status 500 for Player 1628392, Game 42400312
# 2025-06-20 16:03:43,806 - WARNING - Request failed with status 500 for Player 1629614, Game 42400302
# 2025-06-20 16:03:43,955 - WARNING - Request failed with status 500 for Player 1629614, Game 42400302
# 2025-06-20 16:03:44,101 - WARNING - Request failed with status 500 for Player 1629614, Game 42400302
# 2025-06-20 16:03:44,713 - WARNING - Request failed with status 500 for Player 1626157, Game 42400302
# 2025-06-20 16:03:44,896 - WARNING - Request failed with status 500 for Player 1626157, Game 42400302
# 2025-06-20 16:03:45,044 - WARNING - Request failed with status 500 for Player 1626157, Game 42400302
# 2025-06-20 16:03:47,735 - WARNING - Request failed with status 500 for Player 203944, Game 42400313
# 2025-06-20 16:03:47,923 - WARNING - Request failed with status 500 for Player 203944, Game 42400313
# 2025-06-20 16:03:48,081 - WARNING - Request failed with status 500 for Player 203944, Game 42400313
# 2025-06-20 16:03:48,864 - WARNING - Request failed with status 500 for Player 203497, Game 42400313
# 2025-06-20 16:03:49,055 - WARNING - Request failed with status 500 for Player 203497, Game 42400313
# 2025-06-20 16:03:49,215 - WARNING - Request failed with status 500 for Player 203497, Game 42400313
# 2025-06-20 16:03:51,771 - WARNING - Request failed with status 500 for Player 1630174, Game 42400303
# 2025-06-20 16:03:51,947 - WARNING - Request failed with status 500 for Player 1630174, Game 42400303
# 2025-06-20 16:03:52,102 - WARNING - Request failed with status 500 for Player 1630174, Game 42400303
# 2025-06-20 16:03:53,902 - WARNING - Request failed with status 500 for Player 1631096, Game 42400314
# 2025-06-20 16:03:54,052 - WARNING - Request failed with status 500 for Player 1631096, Game 42400314
# 2025-06-20 16:03:54,306 - WARNING - Request failed with status 500 for Player 1631096, Game 42400314
# 2025-06-20 16:03:55,064 - WARNING - Request failed with status 500 for Player 1628392, Game 42400314
# 2025-06-20 16:03:55,216 - WARNING - Request failed with status 500 for Player 1628392, Game 42400314
# 2025-06-20 16:03:55,370 - WARNING - Request failed with status 500 for Player 1628392, Game 42400314
# 2025-06-20 16:03:56,904 - WARNING - Request failed with status 500 for Player 1629614, Game 42400304
# 2025-06-20 16:03:57,092 - WARNING - Request failed with status 500 for Player 1629614, Game 42400304
# 2025-06-20 16:03:57,251 - WARNING - Request failed with status 500 for Player 1629614, Game 42400304
# 2025-06-20 16:03:58,164 - WARNING - Request failed with status 500 for Player 1631096, Game 42400315
# 2025-06-20 16:03:58,328 - WARNING - Request failed with status 500 for Player 1631096, Game 42400315
# 2025-06-20 16:03:58,485 - WARNING - Request failed with status 500 for Player 1631096, Game 42400315
# 2025-06-20 16:03:59,137 - WARNING - Request failed with status 500 for Player 1630174, Game 42400305
# 2025-06-20 16:03:59,323 - WARNING - Request failed with status 500 for Player 1630174, Game 42400305
# 2025-06-20 16:03:59,481 - WARNING - Request failed with status 500 for Player 1630174, Game 42400305
# 2025-06-20 16:04:03,253 - WARNING - Request failed with status 500 for Player 1630174, Game 42400306
# 2025-06-20 16:04:03,492 - WARNING - Request failed with status 500 for Player 1630174, Game 42400306
# 2025-06-20 16:04:03,854 - WARNING - Request failed with status 500 for Player 1630174, Game 42400306
# 2025-06-20 16:04:09,133 - WARNING - Request failed with status 500 for Player 1627783, Game 42400401
# 2025-06-20 16:04:09,284 - WARNING - Request failed with status 500 for Player 1627783, Game 42400401
# 2025-06-20 16:04:09,558 - WARNING - Request failed with status 500 for Player 1627783, Game 42400401
# 2025-06-20 16:04:10,403 - WARNING - Request failed with status 500 for Player 1641717, Game 42400402
# 2025-06-20 16:04:10,768 - WARNING - Request failed with status 500 for Player 1641717, Game 42400402
# 2025-06-20 16:04:11,060 - WARNING - Request failed with status 500 for Player 1641717, Game 42400402
# 2025-06-20 16:04:14,322 - WARNING - Request failed with status 500 for Player 1627783, Game 42400402
# 2025-06-20 16:04:14,514 - WARNING - Request failed with status 500 for Player 1627783, Game 42400402
# 2025-06-20 16:04:14,661 - WARNING - Request failed with status 500 for Player 1627783, Game 42400402
# 2025-06-20 16:04:15,272 - WARNING - Request failed with status 500 for Player 1630169, Game 42400402
# 2025-06-20 16:04:15,433 - WARNING - Request failed with status 500 for Player 1630169, Game 42400402
# 2025-06-20 16:04:15,587 - WARNING - Request failed with status 500 for Player 1630169, Game 42400402
# 2025-06-20 16:04:17,132 - WARNING - Request failed with status 500 for Player 1630169, Game 42400404
# 2025-06-20 16:04:17,276 - WARNING - Request failed with status 500 for Player 1630169, Game 42400404
# 2025-06-20 16:04:17,444 - WARNING - Request failed with status 500 for Player 1630169, Game 42400404
# 2025-06-20 16:04:17,454 - INFO - Saved 2025 batch 3785 with 188 records to batch_3785_20250620_160417.csv
# 2025-06-20 16:04:19,213 - INFO - === SCRAPING COMPLETE ===
# 2025-06-20 16:04:19,214 - INFO - Attempted to scrape: 644
# 2025-06-20 16:04:19,215 - INFO - Successful requests with data: 15
# 2025-06-20 16:04:19,217 - INFO - Successful requests with no data: 281
# 2025-06-20 16:04:19,217 - INFO - Failed requests: 348
# 2025-06-20 16:04:19,219 - INFO - New video records saved: 188
# 2025-06-20 16:04:19,220 - INFO - Overall success rate: 46.0%
# 2025-06-20 16:04:19,220 - INFO - Data found rate: 2.3%
# 2025-06-20 16:04:19,229 - INFO - Found 7 year directories
# 2025-06-20 16:04:19,230 - INFO - Combined file already exists for 2019, skipping...
# 2025-06-20 16:04:19,231 - INFO - Combined file already exists for 2020, skipping...
# 2025-06-20 16:04:19,232 - INFO - Combined file already exists for 2021, skipping...
# 2025-06-20 16:04:19,233 - INFO - Combined file already exists for 2022, skipping...
# 2025-06-20 16:04:19,234 - INFO - Processing 2023: Found 510 batch files
# 2025-06-20 16:04:22,576 - INFO - ✓ Combined file saved: scraped_data/year_2023/combined_video_details_2023.csv with 247934 total records
# 2025-06-20 16:04:22,577 - INFO - Combined file already exists for 2024, skipping...
# 2025-06-20 16:04:22,578 - INFO - Combined file already exists for 2025, skipping...
# 2025-06-20 16:04:22,587 - INFO -
# === DATA SUMMARY BY YEAR ===
# 2025-06-20 16:04:22,859 - INFO - 2019: 243,791 records (combined)
# 2025-06-20 16:04:23,112 - INFO - 2020: 212,869 records (combined)
# 2025-06-20 16:04:23,322 - INFO - 2021: 219,375 records (combined)
# 2025-06-20 16:04:23,575 - INFO - 2022: 244,270 records (combined)
# 2025-06-20 16:04:23,846 - INFO - 2023: 247,934 records (combined)
# 2025-06-20 16:04:24,145 - INFO - 2024: 247,452 records (combined)
# 2025-06-20 16:04:24,496 - INFO - 2025: 248,577 records (combined)
# 2025-06-20 16:04:24,497 - INFO -
# Total records across all years: 1,664,268
# 2025-06-20 16:04:25,024 - INFO - Successfully loaded JSON from scrape_log.json with 188540 entries
# 2025-06-20 16:04:25,053 - INFO -
# === SCRAPE LOG ANALYSIS ===
# 2025-06-20 16:04:25,055 - INFO - Total attempts logged: 188540
# 2025-06-20 16:04:25,056 - INFO - Successful attempts: 188108
# 2025-06-20 16:04:25,058 - INFO - Failed attempts: 432
# 2025-06-20 16:04:25,059 - INFO - Success rate: 99.8%
# 2025-06-20 16:04:25,060 - INFO - Total video records recorded in log: 445461
# 2025-06-20 16:04:25,134 - INFO -
# Breakdown by year:
# 2025-06-20 16:04:25,135 - INFO -   2019: 2272 attempts, 2267 successful (99.8%), 220 records
# 2025-06-20 16:04:25,136 - INFO -   2020: 10048 attempts, 10048 successful (100.0%), 78541 records
# 2025-06-20 16:04:25,137 - INFO -   2021: 24915 attempts, 24913 successful (100.0%), 219375 records
# 2025-06-20 16:04:25,137 - INFO -   2022: 2568 attempts, 2568 successful (100.0%), 1134 records
# 2025-06-20 16:04:25,138 - INFO -   2023: 2384 attempts, 2384 successful (100.0%), 1204 records
# 2025-06-20 16:04:25,139 - INFO -   2024: 2493 attempts, 2493 successful (100.0%), 1497 records
# 2025-06-20 16:04:25,140 - INFO -   2025: 143860 attempts, 143435 successful (99.7%), 143490 records
