# %%
import requests
import pandas as pd
import time
import os
from datetime import datetime
import sys
import json
import asyncio
import aiohttp
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
from queue import Queue
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class NBAScraper:
    def __init__(self, max_concurrent_requests=10, request_delay=0.1, 
                 batch_size=50, output_dir="scraped_data"):
        self.max_concurrent_requests = max_concurrent_requests
        self.request_delay = request_delay
        self.batch_size = batch_size
        self.output_dir = output_dir
        self.session = None
        self.log_data = {}
        self.lock = threading.Lock()
        
        # Headers for requests
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
            "Referer": "https://www.nba.com",
            "Accept": "application/json",
            "Accept-Language": "en-US,en;q=0.9",
            "Origin": "https://www.nba.com"
        }

    def load_scrape_log(self, log_file="scrape_log.json"):
        """Load the scrape log that tracks all attempted scrapes"""
        if os.path.exists(log_file):
            try:
                with open(log_file, 'r') as f:
                    self.log_data = json.load(f)
                logger.info(f"Loaded scrape log with {len(self.log_data)} previous attempts")
            except Exception as e:
                logger.error(f"Error loading scrape log: {e}")
                self.log_data = {}
        else:
            logger.info("No existing scrape log found. Starting fresh.")
            self.log_data = {}

    def save_scrape_log(self, log_file="scrape_log.json"):
        """Save the scrape log to disk"""
        try:
            with open(log_file, 'w') as f:
                json.dump(self.log_data, f, indent=2)
        except Exception as e:
            logger.error(f"Error saving scrape log: {e}")

    def update_scrape_log(self, player_id, game_id, team_id, player_name, year, 
                         success, record_count=0, error_msg=None):
        """Thread-safe update of scrape log"""
        key = f"{player_id}_{game_id}"
        with self.lock:
            self.log_data[key] = {
                "player_id": str(player_id),
                "game_id": str(game_id),
                "team_id": str(team_id),
                "player_name": player_name,
                "year": year,
                "timestamp": datetime.now().isoformat(),
                "success": success,
                "record_count": record_count,
                "error_msg": error_msg
            }

    async def fetch_details_async(self, session, game_id, player_id, team_id, context_measure="DEF_FGA"):
        """Async version of fetch_details"""
        base_url = "https://stats.nba.com/stats/videodetailsasset"
        
        params = {
            "GameID": '00'+str(game_id),
            "GameEventID": "",
            "PlayerID": str(player_id),
            "TeamID": str(team_id),
            "Season": "",
            "SeasonType": "",
            "AheadBehind": "",
            "CFID": "",
            "CFPARAMS": "",
            "ClutchTime": "",
            "Conference": "",
            "ContextFilter": "",
            "ContextMeasure": context_measure,
            "DateFrom": "",
            "DateTo": "",
            "Division": "",
            "EndPeriod": 0,
            "EndRange": 40800,
            "GROUP_ID": "",
            "GameSegment": "",
            "GroupID": "",
            "GroupMode": "",
            "GroupQuantity": 5,
            "LastNGames": 0,
            "Location": "",
            "Month": 0,
            "OnOff": "",
            "OppPlayerID": "",
            "OpponentTeamID": 0,
            "Outcome": "",
            "PORound": 0,
            "Period": 0,
            "PlayerID1": "",
            "PlayerID2": "",
            "PlayerID3": "",
            "PlayerID4": "",
            "PlayerID5": "",
            "PlayerPosition": "",
            "PointDiff": "",
            "Position": "",
            "RangeType": 0,
            "RookieYear": "",
            "SeasonSegment": "",
            "ShotClockRange": "",
            "StartPeriod": 0,
            "StartRange": 0,
            "StarterBench": "",
            "VsConference": "",
            "VsDivision": "",
            "VsPlayerID1": "",
            "VsPlayerID2": "",
            "VsPlayerID3": "",
            "VsPlayerID4": "",
            "VsPlayerID5": "",
            "VsTeamID": ""
        }
        
        try:
            async with session.get(base_url, headers=self.headers, params=params, timeout=30) as response:
                if response.status == 200:
                    return await response.json()
                else:
                    logger.warning(f"Request failed with status {response.status} for Player {player_id}, Game {game_id}")
                    return None
        except Exception as e:
            logger.error(f"Request error for Player {player_id}, Game {game_id}: {e}")
            return None

    def process_video_data(self, video_json, player_id, team_id, player_name, year):
        """Process the video JSON response into a DataFrame"""
        try:
            if video_json and 'resultSets' in video_json and 'playlist' in video_json['resultSets']:
                playlist = video_json['resultSets']['playlist']
                if playlist:
                    df = pd.DataFrame(playlist)
                    if not df.empty and all(col in df.columns for col in ['gi', 'ei', 'dsc']):
                        df = df[['gi', 'ei', 'dsc']]
                        df['def_id'] = player_id
                        df['team_id'] = team_id
                        df['player_name'] = player_name
                        df['year'] = year
                        return df
            return None
        except Exception as e:
            logger.error(f"Error processing data for Player {player_id}: {e}")
            return None

    async def process_single_request(self, session, player_id, game_id, team_id, player_name, year, context_measure="DEF_FGA"):
        """Process a single request asynchronously"""
        # Add small delay to avoid overwhelming the server
        await asyncio.sleep(self.request_delay)
        
        video_json = await self.fetch_details_async(session, game_id, player_id, team_id, context_measure)
        
        if video_json:
            processed_df = self.process_video_data(video_json, player_id, team_id, player_name, year)
            
            if processed_df is not None and not processed_df.empty:
                record_count = len(processed_df)
                self.update_scrape_log(player_id, game_id, team_id, player_name, year, True, record_count)
                return processed_df, True, record_count
            else:
                self.update_scrape_log(player_id, game_id, team_id, player_name, year, True, 0)
                return None, True, 0
        else:
            self.update_scrape_log(player_id, game_id, team_id, player_name, year, False, 0, "API request failed")
            return None, False, 0

    async def scrape_batch_async(self, batch_data, context_measure="DEF_FGA"):
        """Scrape a batch of requests asynchronously"""
        connector = aiohttp.TCPConnector(limit=self.max_concurrent_requests, limit_per_host=self.max_concurrent_requests)
        timeout = aiohttp.ClientTimeout(total=60)
        
        async with aiohttp.ClientSession(connector=connector, timeout=timeout) as session:
            # Create semaphore to limit concurrent requests
            semaphore = asyncio.Semaphore(self.max_concurrent_requests)
            
            async def limited_request(row):
                async with semaphore:
                    return await self.process_single_request(
                        session, row['PLAYER_ID'], row['GAME_ID'], row['TEAM_ID'], 
                        row['PLAYER_NAME'], row['year'], context_measure
                    )
            
            # Execute all requests concurrently
            tasks = [limited_request(row) for _, row in batch_data.iterrows()]
            results = await asyncio.gather(*tasks, return_exceptions=True)
            
            return results

    def save_batch_data_by_year(self, year_data_dict, batch_num):
        """Save batch data organized by year"""
        if not os.path.exists(self.output_dir):
            os.makedirs(self.output_dir)
        
        total_records_saved = 0
        
        for year, data_list in year_data_dict.items():
            if data_list:
                # Create year-specific directory
                year_dir = os.path.join(self.output_dir, f"year_{year}")
                if not os.path.exists(year_dir):
                    os.makedirs(year_dir)
                
                # Combine all data for this year
                combined_df = pd.concat(data_list, ignore_index=True)
                
                # Save with timestamp and batch number
                filename = f"{year_dir}/batch_{batch_num}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
                combined_df.to_csv(filename, index=False)
                
                records_count = len(combined_df)
                total_records_saved += records_count
                logger.info(f"Saved {year} batch {batch_num} with {records_count} records to {filename}")
        
        return total_records_saved

    def load_already_scraped_combinations_from_files(self):
        """Load all previously scraped combinations from existing batch files"""
        already_scraped = set()
        
        if not os.path.exists(self.output_dir):
            logger.info("No existing scraped data directory found.")
            return already_scraped
        
        # Find all year directories
        year_dirs = [d for d in os.listdir(self.output_dir) if d.startswith('year_') and os.path.isdir(os.path.join(self.output_dir, d))]
        
        if not year_dirs:
            logger.info("No existing year directories found.")
            return already_scraped
        
        logger.info(f"Checking existing scraped data in {len(year_dirs)} year directories...")
        
        for year_dir in year_dirs:
            year_path = os.path.join(self.output_dir, year_dir)
            year = year_dir.replace('year_', '')
            
            # Check for combined file first
            combined_file = os.path.join(year_path, f"combined_video_details_{year}.csv")
            
            if os.path.exists(combined_file):
                logger.info(f"  Loading from combined file: {combined_file}")
                try:
                    df = pd.read_csv(combined_file)
                    if 'def_id' in df.columns and 'gi' in df.columns:
                        combinations = set(zip(df['def_id'].astype(str), df['gi'].astype(str)))
                        already_scraped.update(combinations)
                        logger.info(f"    Found {len(combinations)} combinations for {year}")
                except Exception as e:
                    logger.error(f"    Error reading {combined_file}: {e}")
            else:
                # Check batch files
                batch_files = [f for f in os.listdir(year_path) if f.startswith('batch_') and f.endswith('.csv')]
                year_combinations = 0
                
                for batch_file in batch_files:
                    batch_path = os.path.join(year_path, batch_file)
                    try:
                        df = pd.read_csv(batch_path)
                        if 'def_id' in df.columns and 'gi' in df.columns:
                            combinations = set(zip(df['def_id'].astype(str), df['gi'].astype(str)))
                            already_scraped.update(combinations)
                            year_combinations += len(combinations)
                    except Exception as e:
                        logger.error(f"    Error reading {batch_path}: {e}")
                
                if year_combinations > 0:
                    logger.info(f"  Found {year_combinations} combinations from {len(batch_files)} batch files for {year}")
        
        logger.info(f"Total unique combinations with data in CSV files: {len(already_scraped)}")
        return already_scraped

    def scrape_nba_video_details(self, master_record_path, context_measure="DEF_FGA", 
                               force_retry_failed=False):
        """Main scraper function with async processing"""
        
        # Load scrape log
        logger.info("=== LOADING SCRAPE LOG ===")
        self.load_scrape_log()
        
        # Load already scraped combinations from CSV files
        logger.info("=== LOADING EXISTING CSV DATA ===")
        csv_combinations = self.load_already_scraped_combinations_from_files()
        
        # Migrate CSV data to log if needed
        self.migrate_csv_data_to_log(csv_combinations)
        
        # Load master record
        try:
            master_record = pd.read_csv(master_record_path)
            master_record['TEAM_ID'] = master_record['TEAM_ID'].astype(int)
            master_record['PLAYER_ID'] = master_record['PLAYER_ID'].astype(int)
            master_record = master_record[master_record.year > 2024]
            logger.info(f"Loaded master record with {len(master_record)} rows")
        except Exception as e:
            logger.error(f"Error loading master record: {e}")
            return
        
        # Get unique combinations and filter
        unique_combinations = master_record[['PLAYER_ID', 'GAME_ID', 'TEAM_ID', 'PLAYER_NAME', 'year']].drop_duplicates()
        unique_combinations['scrape_key'] = unique_combinations['PLAYER_ID'].astype(str) + "_" + unique_combinations['GAME_ID'].astype(str)
        
        # Filter based on scrape log
        already_attempted = set(self.log_data.keys())
        unique_combinations['log_status'] = unique_combinations['scrape_key'].apply(
            lambda x: 'never_attempted' if x not in already_attempted else 
                     ('successful' if self.log_data[x]['success'] else 'failed')
        )
        
        never_attempted = unique_combinations[unique_combinations['log_status'] == 'never_attempted']
        previously_failed = unique_combinations[unique_combinations['log_status'] == 'failed']
        
        # Determine what to scrape
        if force_retry_failed:
            to_scrape_df = pd.concat([never_attempted, previously_failed])
            logger.info(f"Force retry enabled: Will attempt {len(to_scrape_df)} combinations")
        else:
            to_scrape_df = never_attempted
            logger.info(f"Will attempt {len(to_scrape_df)} never-attempted combinations")
        
        if len(to_scrape_df) == 0:
            logger.info("🎉 No combinations to scrape!")
            return
        
        # Process in batches
        logger.info("=== STARTING ASYNC SCRAPING PROCESS ===")
        
        total_batches = (len(to_scrape_df) + self.batch_size - 1) // self.batch_size
        successful_requests = 0
        failed_requests = 0
        total_records_saved = 0
        
        for batch_idx in range(total_batches):
            start_idx = batch_idx * self.batch_size
            end_idx = min((batch_idx + 1) * self.batch_size, len(to_scrape_df))
            batch_data = to_scrape_df.iloc[start_idx:end_idx]
            
            logger.info(f"Processing batch {batch_idx + 1}/{total_batches} ({len(batch_data)} items)")
            
            # Process batch asynchronously
            try:
                results = asyncio.run(self.scrape_batch_async(batch_data, context_measure))
                
                # Process results
                year_data = {}
                batch_successful = 0
                batch_failed = 0
                
                for i, result in enumerate(results):
                    if isinstance(result, Exception):
                        logger.error(f"Exception in batch processing: {result}")
                        batch_failed += 1
                        continue
                    
                    processed_df, success, record_count = result
                    row = batch_data.iloc[i]
                    
                    if success:
                        batch_successful += 1
                        if processed_df is not None and not processed_df.empty:
                            year = row['year']
                            if year not in year_data:
                                year_data[year] = []
                            year_data[year].append(processed_df)
                    else:
                        batch_failed += 1
                
                # Save batch data
                if any(year_data.values()):
                    records_saved = self.save_batch_data_by_year(year_data, batch_idx + 1)
                    total_records_saved += records_saved
                
                successful_requests += batch_successful
                failed_requests += batch_failed
                
                logger.info(f"Batch {batch_idx + 1} complete: {batch_successful} successful, {batch_failed} failed")
                
                # Save log periodically
                if (batch_idx + 1) % 5 == 0:
                    self.save_scrape_log()
                
            except Exception as e:
                logger.error(f"Error processing batch {batch_idx + 1}: {e}")
                failed_requests += len(batch_data)
        
        # Save final log
        self.save_scrape_log()
        
        # Print summary
        logger.info("=== SCRAPING COMPLETE ===")
        logger.info(f"Attempted to scrape: {len(to_scrape_df)}")
        logger.info(f"Successful requests: {successful_requests}")
        logger.info(f"Failed requests: {failed_requests}")
        logger.info(f"New video records saved: {total_records_saved}")
        if len(to_scrape_df) > 0:
            logger.info(f"Success rate: {(successful_requests/len(to_scrape_df))*100:.1f}%")

    def migrate_csv_data_to_log(self, csv_combinations):
        """Migrate existing CSV data to the scrape log"""
        migrated_count = 0
        for player_id, game_id in csv_combinations:
            key = f"{player_id}_{game_id}"
            if key not in self.log_data:
                self.log_data[key] = {
                    "player_id": str(player_id),
                    "game_id": str(game_id),
                    "team_id": "unknown",
                    "player_name": "unknown",
                    "year": "unknown",
                    "timestamp": "migrated_from_csv",
                    "success": True,
                    "record_count": 1,
                    "error_msg": None
                }
                migrated_count += 1
        
        if migrated_count > 0:
            logger.info(f"Migrated {migrated_count} successful scrapes from CSV files to log")


def main():
    """Main function to run the optimized scraper"""
    scraper = NBAScraper(
        max_concurrent_requests=15,  # Adjust based on your system and API limits
        request_delay=0.05,  # Much smaller delay between requests
        batch_size=100,  # Larger batch size for efficiency
        output_dir="scraped_data"
    )
    
    scraper.scrape_nba_video_details(
        master_record_path='master_record.csv',
        context_measure="DEF_FGA",
        force_retry_failed=False
    )

if __name__ == "__main__":
    main()
# Out:
# 2025-06-13 15:37:48,858 - INFO - === LOADING SCRAPE LOG ===
# 2025-06-13 15:37:48,872 - INFO - Loaded scrape log with 4040 previous attempts
# 2025-06-13 15:37:48,873 - INFO - === LOADING EXISTING CSV DATA ===
# 2025-06-13 15:37:48,875 - INFO - Checking existing scraped data in 1 year directories...
# 2025-06-13 15:37:49,056 - INFO -   Found 3850 combinations from 77 batch files for 2025
# 2025-06-13 15:37:49,057 - INFO - Total unique combinations with data in CSV files: 3850
# 2025-06-13 15:37:49,401 - INFO - Loaded master record with 28019 rows
# 2025-06-13 15:37:49,442 - INFO - Will attempt 23979 never-attempted combinations
# 2025-06-13 15:37:49,443 - INFO - === STARTING ASYNC SCRAPING PROCESS ===
# 2025-06-13 15:37:49,444 - INFO - Processing batch 1/240 (100 items)
# 2025-06-13 15:37:49,446 - ERROR - Error processing batch 1: asyncio.run() cannot be called from a running event loop
# /tmp/ipykernel_1338/3001866834.py:407: RuntimeWarning: coroutine 'NBAScraper.scrape_batch_async' was never awaited
#   failed_requests += len(batch_data)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 2025-06-13 15:37:49,454 - INFO - Processing batch 2/240 (100 items)
# 2025-06-13 15:37:49,455 - ERROR - Error processing batch 2: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,456 - INFO - Processing batch 3/240 (100 items)
# 2025-06-13 15:37:49,457 - ERROR - Error processing batch 3: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,458 - INFO - Processing batch 4/240 (100 items)
# 2025-06-13 15:37:49,459 - ERROR - Error processing batch 4: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,459 - INFO - Processing batch 5/240 (100 items)
# 2025-06-13 15:37:49,460 - ERROR - Error processing batch 5: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,461 - INFO - Processing batch 6/240 (100 items)
# 2025-06-13 15:37:49,462 - ERROR - Error processing batch 6: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,463 - INFO - Processing batch 7/240 (100 items)
# 2025-06-13 15:37:49,464 - ERROR - Error processing batch 7: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,465 - INFO - Processing batch 8/240 (100 items)
# 2025-06-13 15:37:49,465 - ERROR - Error processing batch 8: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,466 - INFO - Processing batch 9/240 (100 items)
# 2025-06-13 15:37:49,467 - ERROR - Error processing batch 9: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,468 - INFO - Processing batch 10/240 (100 items)
# 2025-06-13 15:37:49,469 - ERROR - Error processing batch 10: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,470 - INFO - Processing batch 11/240 (100 items)
# 2025-06-13 15:37:49,470 - ERROR - Error processing batch 11: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,471 - INFO - Processing batch 12/240 (100 items)
# 2025-06-13 15:37:49,472 - ERROR - Error processing batch 12: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,473 - INFO - Processing batch 13/240 (100 items)
# 2025-06-13 15:37:49,474 - ERROR - Error processing batch 13: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,474 - INFO - Processing batch 14/240 (100 items)
# 2025-06-13 15:37:49,475 - ERROR - Error processing batch 14: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,476 - INFO - Processing batch 15/240 (100 items)
# 2025-06-13 15:37:49,477 - ERROR - Error processing batch 15: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,481 - INFO - Processing batch 16/240 (100 items)
# 2025-06-13 15:37:49,482 - ERROR - Error processing batch 16: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,484 - INFO - Processing batch 17/240 (100 items)
# 2025-06-13 15:37:49,484 - ERROR - Error processing batch 17: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,486 - INFO - Processing batch 18/240 (100 items)
# 2025-06-13 15:37:49,487 - ERROR - Error processing batch 18: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,488 - INFO - Processing batch 19/240 (100 items)
# 2025-06-13 15:37:49,488 - ERROR - Error processing batch 19: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,489 - INFO - Processing batch 20/240 (100 items)
# 2025-06-13 15:37:49,490 - ERROR - Error processing batch 20: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,491 - INFO - Processing batch 21/240 (100 items)
# 2025-06-13 15:37:49,491 - ERROR - Error processing batch 21: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,492 - INFO - Processing batch 22/240 (100 items)
# 2025-06-13 15:37:49,493 - ERROR - Error processing batch 22: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,494 - INFO - Processing batch 23/240 (100 items)
# 2025-06-13 15:37:49,495 - ERROR - Error processing batch 23: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,496 - INFO - Processing batch 24/240 (100 items)
# 2025-06-13 15:37:49,496 - ERROR - Error processing batch 24: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,498 - INFO - Processing batch 25/240 (100 items)
# 2025-06-13 15:37:49,499 - ERROR - Error processing batch 25: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,500 - INFO - Processing batch 26/240 (100 items)
# 2025-06-13 15:37:49,501 - ERROR - Error processing batch 26: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,501 - INFO - Processing batch 27/240 (100 items)
# 2025-06-13 15:37:49,502 - ERROR - Error processing batch 27: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,503 - INFO - Processing batch 28/240 (100 items)
# 2025-06-13 15:37:49,504 - ERROR - Error processing batch 28: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,505 - INFO - Processing batch 29/240 (100 items)
# 2025-06-13 15:37:49,506 - ERROR - Error processing batch 29: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,508 - INFO - Processing batch 30/240 (100 items)
# 2025-06-13 15:37:49,508 - ERROR - Error processing batch 30: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,509 - INFO - Processing batch 31/240 (100 items)
# 2025-06-13 15:37:49,510 - ERROR - Error processing batch 31: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,511 - INFO - Processing batch 32/240 (100 items)
# 2025-06-13 15:37:49,511 - ERROR - Error processing batch 32: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,512 - INFO - Processing batch 33/240 (100 items)
# 2025-06-13 15:37:49,513 - ERROR - Error processing batch 33: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,513 - INFO - Processing batch 34/240 (100 items)
# 2025-06-13 15:37:49,515 - ERROR - Error processing batch 34: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,516 - INFO - Processing batch 35/240 (100 items)
# 2025-06-13 15:37:49,518 - ERROR - Error processing batch 35: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,519 - INFO - Processing batch 36/240 (100 items)
# 2025-06-13 15:37:49,520 - ERROR - Error processing batch 36: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,520 - INFO - Processing batch 37/240 (100 items)
# 2025-06-13 15:37:49,521 - ERROR - Error processing batch 37: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,522 - INFO - Processing batch 38/240 (100 items)
# 2025-06-13 15:37:49,522 - ERROR - Error processing batch 38: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,524 - INFO - Processing batch 39/240 (100 items)
# 2025-06-13 15:37:49,525 - ERROR - Error processing batch 39: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,525 - INFO - Processing batch 40/240 (100 items)
# 2025-06-13 15:37:49,526 - ERROR - Error processing batch 40: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,527 - INFO - Processing batch 41/240 (100 items)
# 2025-06-13 15:37:49,528 - ERROR - Error processing batch 41: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,528 - INFO - Processing batch 42/240 (100 items)
# 2025-06-13 15:37:49,529 - ERROR - Error processing batch 42: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,530 - INFO - Processing batch 43/240 (100 items)
# 2025-06-13 15:37:49,530 - ERROR - Error processing batch 43: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,531 - INFO - Processing batch 44/240 (100 items)
# 2025-06-13 15:37:49,532 - ERROR - Error processing batch 44: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,533 - INFO - Processing batch 45/240 (100 items)
# 2025-06-13 15:37:49,533 - ERROR - Error processing batch 45: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,534 - INFO - Processing batch 46/240 (100 items)
# 2025-06-13 15:37:49,535 - ERROR - Error processing batch 46: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,535 - INFO - Processing batch 47/240 (100 items)
# 2025-06-13 15:37:49,536 - ERROR - Error processing batch 47: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,537 - INFO - Processing batch 48/240 (100 items)
# 2025-06-13 15:37:49,538 - ERROR - Error processing batch 48: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,539 - INFO - Processing batch 49/240 (100 items)
# 2025-06-13 15:37:49,539 - ERROR - Error processing batch 49: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,540 - INFO - Processing batch 50/240 (100 items)
# 2025-06-13 15:37:49,541 - ERROR - Error processing batch 50: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,542 - INFO - Processing batch 51/240 (100 items)
# 2025-06-13 15:37:49,542 - ERROR - Error processing batch 51: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,543 - INFO - Processing batch 52/240 (100 items)
# 2025-06-13 15:37:49,544 - ERROR - Error processing batch 52: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,544 - INFO - Processing batch 53/240 (100 items)
# 2025-06-13 15:37:49,545 - ERROR - Error processing batch 53: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,546 - INFO - Processing batch 54/240 (100 items)
# 2025-06-13 15:37:49,547 - ERROR - Error processing batch 54: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,549 - INFO - Processing batch 55/240 (100 items)
# 2025-06-13 15:37:49,549 - ERROR - Error processing batch 55: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,550 - INFO - Processing batch 56/240 (100 items)
# 2025-06-13 15:37:49,551 - ERROR - Error processing batch 56: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,551 - INFO - Processing batch 57/240 (100 items)
# 2025-06-13 15:37:49,552 - ERROR - Error processing batch 57: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,553 - INFO - Processing batch 58/240 (100 items)
# 2025-06-13 15:37:49,554 - ERROR - Error processing batch 58: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,555 - INFO - Processing batch 59/240 (100 items)
# 2025-06-13 15:37:49,555 - ERROR - Error processing batch 59: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,556 - INFO - Processing batch 60/240 (100 items)
# 2025-06-13 15:37:49,556 - ERROR - Error processing batch 60: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,558 - INFO - Processing batch 61/240 (100 items)
# 2025-06-13 15:37:49,558 - ERROR - Error processing batch 61: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,559 - INFO - Processing batch 62/240 (100 items)
# 2025-06-13 15:37:49,559 - ERROR - Error processing batch 62: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,560 - INFO - Processing batch 63/240 (100 items)
# 2025-06-13 15:37:49,561 - ERROR - Error processing batch 63: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,561 - INFO - Processing batch 64/240 (100 items)
# 2025-06-13 15:37:49,563 - ERROR - Error processing batch 64: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,564 - INFO - Processing batch 65/240 (100 items)
# 2025-06-13 15:37:49,564 - ERROR - Error processing batch 65: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,565 - INFO - Processing batch 66/240 (100 items)
# 2025-06-13 15:37:49,566 - ERROR - Error processing batch 66: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,566 - INFO - Processing batch 67/240 (100 items)
# 2025-06-13 15:37:49,567 - ERROR - Error processing batch 67: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,568 - INFO - Processing batch 68/240 (100 items)
# 2025-06-13 15:37:49,569 - ERROR - Error processing batch 68: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,569 - INFO - Processing batch 69/240 (100 items)
# 2025-06-13 15:37:49,570 - ERROR - Error processing batch 69: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,572 - INFO - Processing batch 70/240 (100 items)
# 2025-06-13 15:37:49,573 - ERROR - Error processing batch 70: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,573 - INFO - Processing batch 71/240 (100 items)
# 2025-06-13 15:37:49,574 - ERROR - Error processing batch 71: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,575 - INFO - Processing batch 72/240 (100 items)
# 2025-06-13 15:37:49,575 - ERROR - Error processing batch 72: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,576 - INFO - Processing batch 73/240 (100 items)
# 2025-06-13 15:37:49,577 - ERROR - Error processing batch 73: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,577 - INFO - Processing batch 74/240 (100 items)
# 2025-06-13 15:37:49,578 - ERROR - Error processing batch 74: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,579 - INFO - Processing batch 75/240 (100 items)
# 2025-06-13 15:37:49,579 - ERROR - Error processing batch 75: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,580 - INFO - Processing batch 76/240 (100 items)
# 2025-06-13 15:37:49,583 - ERROR - Error processing batch 76: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,585 - INFO - Processing batch 77/240 (100 items)
# 2025-06-13 15:37:49,585 - ERROR - Error processing batch 77: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,590 - INFO - Processing batch 78/240 (100 items)
# 2025-06-13 15:37:49,591 - ERROR - Error processing batch 78: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,591 - INFO - Processing batch 79/240 (100 items)
# 2025-06-13 15:37:49,592 - ERROR - Error processing batch 79: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,593 - INFO - Processing batch 80/240 (100 items)
# 2025-06-13 15:37:49,593 - ERROR - Error processing batch 80: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,594 - INFO - Processing batch 81/240 (100 items)
# 2025-06-13 15:37:49,595 - ERROR - Error processing batch 81: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,596 - INFO - Processing batch 82/240 (100 items)
# 2025-06-13 15:37:49,596 - ERROR - Error processing batch 82: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,597 - INFO - Processing batch 83/240 (100 items)
# 2025-06-13 15:37:49,597 - ERROR - Error processing batch 83: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,598 - INFO - Processing batch 84/240 (100 items)
# 2025-06-13 15:37:49,599 - ERROR - Error processing batch 84: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,600 - INFO - Processing batch 85/240 (100 items)
# 2025-06-13 15:37:49,601 - ERROR - Error processing batch 85: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,602 - INFO - Processing batch 86/240 (100 items)
# 2025-06-13 15:37:49,603 - ERROR - Error processing batch 86: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,604 - INFO - Processing batch 87/240 (100 items)
# 2025-06-13 15:37:49,604 - ERROR - Error processing batch 87: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,605 - INFO - Processing batch 88/240 (100 items)
# 2025-06-13 15:37:49,606 - ERROR - Error processing batch 88: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,607 - INFO - Processing batch 89/240 (100 items)
# 2025-06-13 15:37:49,608 - ERROR - Error processing batch 89: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,609 - INFO - Processing batch 90/240 (100 items)
# 2025-06-13 15:37:49,609 - ERROR - Error processing batch 90: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,610 - INFO - Processing batch 91/240 (100 items)
# 2025-06-13 15:37:49,611 - ERROR - Error processing batch 91: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,611 - INFO - Processing batch 92/240 (100 items)
# 2025-06-13 15:37:49,612 - ERROR - Error processing batch 92: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,613 - INFO - Processing batch 93/240 (100 items)
# 2025-06-13 15:37:49,614 - ERROR - Error processing batch 93: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,614 - INFO - Processing batch 94/240 (100 items)
# 2025-06-13 15:37:49,615 - ERROR - Error processing batch 94: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,616 - INFO - Processing batch 95/240 (100 items)
# 2025-06-13 15:37:49,616 - ERROR - Error processing batch 95: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,617 - INFO - Processing batch 96/240 (100 items)
# 2025-06-13 15:37:49,618 - ERROR - Error processing batch 96: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,619 - INFO - Processing batch 97/240 (100 items)
# 2025-06-13 15:37:49,619 - ERROR - Error processing batch 97: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,620 - INFO - Processing batch 98/240 (100 items)
# 2025-06-13 15:37:49,621 - ERROR - Error processing batch 98: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,621 - INFO - Processing batch 99/240 (100 items)
# 2025-06-13 15:37:49,622 - ERROR - Error processing batch 99: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,623 - INFO - Processing batch 100/240 (100 items)
# 2025-06-13 15:37:49,623 - ERROR - Error processing batch 100: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,624 - INFO - Processing batch 101/240 (100 items)
# 2025-06-13 15:37:49,625 - ERROR - Error processing batch 101: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,626 - INFO - Processing batch 102/240 (100 items)
# 2025-06-13 15:37:49,627 - ERROR - Error processing batch 102: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,628 - INFO - Processing batch 103/240 (100 items)
# 2025-06-13 15:37:49,628 - ERROR - Error processing batch 103: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,629 - INFO - Processing batch 104/240 (100 items)
# 2025-06-13 15:37:49,630 - ERROR - Error processing batch 104: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,630 - INFO - Processing batch 105/240 (100 items)
# 2025-06-13 15:37:49,631 - ERROR - Error processing batch 105: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,631 - INFO - Processing batch 106/240 (100 items)
# 2025-06-13 15:37:49,632 - ERROR - Error processing batch 106: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,633 - INFO - Processing batch 107/240 (100 items)
# 2025-06-13 15:37:49,633 - ERROR - Error processing batch 107: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,634 - INFO - Processing batch 108/240 (100 items)
# 2025-06-13 15:37:49,635 - ERROR - Error processing batch 108: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,635 - INFO - Processing batch 109/240 (100 items)
# 2025-06-13 15:37:49,636 - ERROR - Error processing batch 109: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,637 - INFO - Processing batch 110/240 (100 items)
# 2025-06-13 15:37:49,637 - ERROR - Error processing batch 110: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,638 - INFO - Processing batch 111/240 (100 items)
# 2025-06-13 15:37:49,638 - ERROR - Error processing batch 111: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,644 - INFO - Processing batch 112/240 (100 items)
# 2025-06-13 15:37:49,645 - ERROR - Error processing batch 112: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,645 - INFO - Processing batch 113/240 (100 items)
# 2025-06-13 15:37:49,646 - ERROR - Error processing batch 113: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,646 - INFO - Processing batch 114/240 (100 items)
# 2025-06-13 15:37:49,647 - ERROR - Error processing batch 114: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,648 - INFO - Processing batch 115/240 (100 items)
# 2025-06-13 15:37:49,649 - ERROR - Error processing batch 115: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,649 - INFO - Processing batch 116/240 (100 items)
# 2025-06-13 15:37:49,650 - ERROR - Error processing batch 116: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,651 - INFO - Processing batch 117/240 (100 items)
# 2025-06-13 15:37:49,651 - ERROR - Error processing batch 117: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,652 - INFO - Processing batch 118/240 (100 items)
# 2025-06-13 15:37:49,652 - ERROR - Error processing batch 118: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,653 - INFO - Processing batch 119/240 (100 items)
# 2025-06-13 15:37:49,656 - ERROR - Error processing batch 119: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,657 - INFO - Processing batch 120/240 (100 items)
# 2025-06-13 15:37:49,657 - ERROR - Error processing batch 120: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,658 - INFO - Processing batch 121/240 (100 items)
# 2025-06-13 15:37:49,658 - ERROR - Error processing batch 121: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,659 - INFO - Processing batch 122/240 (100 items)
# 2025-06-13 15:37:49,660 - ERROR - Error processing batch 122: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,661 - INFO - Processing batch 123/240 (100 items)
# 2025-06-13 15:37:49,661 - ERROR - Error processing batch 123: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,666 - INFO - Processing batch 124/240 (100 items)
# 2025-06-13 15:37:49,667 - ERROR - Error processing batch 124: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,668 - INFO - Processing batch 125/240 (100 items)
# 2025-06-13 15:37:49,669 - ERROR - Error processing batch 125: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,670 - INFO - Processing batch 126/240 (100 items)
# 2025-06-13 15:37:49,671 - ERROR - Error processing batch 126: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,672 - INFO - Processing batch 127/240 (100 items)
# 2025-06-13 15:37:49,672 - ERROR - Error processing batch 127: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,673 - INFO - Processing batch 128/240 (100 items)
# 2025-06-13 15:37:49,674 - ERROR - Error processing batch 128: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,675 - INFO - Processing batch 129/240 (100 items)
# 2025-06-13 15:37:49,675 - ERROR - Error processing batch 129: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,676 - INFO - Processing batch 130/240 (100 items)
# 2025-06-13 15:37:49,677 - ERROR - Error processing batch 130: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,678 - INFO - Processing batch 131/240 (100 items)
# 2025-06-13 15:37:49,679 - ERROR - Error processing batch 131: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,679 - INFO - Processing batch 132/240 (100 items)
# 2025-06-13 15:37:49,680 - ERROR - Error processing batch 132: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,681 - INFO - Processing batch 133/240 (100 items)
# 2025-06-13 15:37:49,681 - ERROR - Error processing batch 133: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,682 - INFO - Processing batch 134/240 (100 items)
# 2025-06-13 15:37:49,683 - ERROR - Error processing batch 134: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,683 - INFO - Processing batch 135/240 (100 items)
# 2025-06-13 15:37:49,684 - ERROR - Error processing batch 135: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,685 - INFO - Processing batch 136/240 (100 items)
# 2025-06-13 15:37:49,685 - ERROR - Error processing batch 136: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,686 - INFO - Processing batch 137/240 (100 items)
# 2025-06-13 15:37:49,687 - ERROR - Error processing batch 137: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,688 - INFO - Processing batch 138/240 (100 items)
# 2025-06-13 15:37:49,688 - ERROR - Error processing batch 138: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,689 - INFO - Processing batch 139/240 (100 items)
# 2025-06-13 15:37:49,690 - ERROR - Error processing batch 139: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,691 - INFO - Processing batch 140/240 (100 items)
# 2025-06-13 15:37:49,691 - ERROR - Error processing batch 140: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,693 - INFO - Processing batch 141/240 (100 items)
# 2025-06-13 15:37:49,693 - ERROR - Error processing batch 141: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,695 - INFO - Processing batch 142/240 (100 items)
# 2025-06-13 15:37:49,695 - ERROR - Error processing batch 142: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,696 - INFO - Processing batch 143/240 (100 items)
# 2025-06-13 15:37:49,696 - ERROR - Error processing batch 143: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,697 - INFO - Processing batch 144/240 (100 items)
# 2025-06-13 15:37:49,698 - ERROR - Error processing batch 144: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,698 - INFO - Processing batch 145/240 (100 items)
# 2025-06-13 15:37:49,699 - ERROR - Error processing batch 145: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,700 - INFO - Processing batch 146/240 (100 items)
# 2025-06-13 15:37:49,700 - ERROR - Error processing batch 146: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,701 - INFO - Processing batch 147/240 (100 items)
# 2025-06-13 15:37:49,702 - ERROR - Error processing batch 147: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,703 - INFO - Processing batch 148/240 (100 items)
# 2025-06-13 15:37:49,703 - ERROR - Error processing batch 148: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,704 - INFO - Processing batch 149/240 (100 items)
# 2025-06-13 15:37:49,705 - ERROR - Error processing batch 149: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,707 - INFO - Processing batch 150/240 (100 items)
# 2025-06-13 15:37:49,708 - ERROR - Error processing batch 150: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,709 - INFO - Processing batch 151/240 (100 items)
# 2025-06-13 15:37:49,710 - ERROR - Error processing batch 151: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,710 - INFO - Processing batch 152/240 (100 items)
# 2025-06-13 15:37:49,711 - ERROR - Error processing batch 152: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,713 - INFO - Processing batch 153/240 (100 items)
# 2025-06-13 15:37:49,714 - ERROR - Error processing batch 153: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,715 - INFO - Processing batch 154/240 (100 items)
# 2025-06-13 15:37:49,715 - ERROR - Error processing batch 154: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,716 - INFO - Processing batch 155/240 (100 items)
# 2025-06-13 15:37:49,716 - ERROR - Error processing batch 155: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,717 - INFO - Processing batch 156/240 (100 items)
# 2025-06-13 15:37:49,718 - ERROR - Error processing batch 156: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,718 - INFO - Processing batch 157/240 (100 items)
# 2025-06-13 15:37:49,719 - ERROR - Error processing batch 157: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,720 - INFO - Processing batch 158/240 (100 items)
# 2025-06-13 15:37:49,720 - ERROR - Error processing batch 158: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,722 - INFO - Processing batch 159/240 (100 items)
# 2025-06-13 15:37:49,722 - ERROR - Error processing batch 159: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,723 - INFO - Processing batch 160/240 (100 items)
# 2025-06-13 15:37:49,723 - ERROR - Error processing batch 160: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,724 - INFO - Processing batch 161/240 (100 items)
# 2025-06-13 15:37:49,725 - ERROR - Error processing batch 161: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,726 - INFO - Processing batch 162/240 (100 items)
# 2025-06-13 15:37:49,733 - ERROR - Error processing batch 162: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,734 - INFO - Processing batch 163/240 (100 items)
# 2025-06-13 15:37:49,734 - ERROR - Error processing batch 163: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,735 - INFO - Processing batch 164/240 (100 items)
# 2025-06-13 15:37:49,736 - ERROR - Error processing batch 164: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,736 - INFO - Processing batch 165/240 (100 items)
# 2025-06-13 15:37:49,737 - ERROR - Error processing batch 165: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,738 - INFO - Processing batch 166/240 (100 items)
# 2025-06-13 15:37:49,738 - ERROR - Error processing batch 166: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,739 - INFO - Processing batch 167/240 (100 items)
# 2025-06-13 15:37:49,740 - ERROR - Error processing batch 167: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,741 - INFO - Processing batch 168/240 (100 items)
# 2025-06-13 15:37:49,741 - ERROR - Error processing batch 168: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,742 - INFO - Processing batch 169/240 (100 items)
# 2025-06-13 15:37:49,743 - ERROR - Error processing batch 169: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,743 - INFO - Processing batch 170/240 (100 items)
# 2025-06-13 15:37:49,744 - ERROR - Error processing batch 170: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,745 - INFO - Processing batch 171/240 (100 items)
# 2025-06-13 15:37:49,745 - ERROR - Error processing batch 171: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,746 - INFO - Processing batch 172/240 (100 items)
# 2025-06-13 15:37:49,746 - ERROR - Error processing batch 172: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,747 - INFO - Processing batch 173/240 (100 items)
# 2025-06-13 15:37:49,748 - ERROR - Error processing batch 173: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,748 - INFO - Processing batch 174/240 (100 items)
# 2025-06-13 15:37:49,749 - ERROR - Error processing batch 174: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,750 - INFO - Processing batch 175/240 (100 items)
# 2025-06-13 15:37:49,750 - ERROR - Error processing batch 175: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,751 - INFO - Processing batch 176/240 (100 items)
# 2025-06-13 15:37:49,752 - ERROR - Error processing batch 176: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,753 - INFO - Processing batch 177/240 (100 items)
# 2025-06-13 15:37:49,754 - ERROR - Error processing batch 177: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,755 - INFO - Processing batch 178/240 (100 items)
# 2025-06-13 15:37:49,755 - ERROR - Error processing batch 178: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,757 - INFO - Processing batch 179/240 (100 items)
# 2025-06-13 15:37:49,758 - ERROR - Error processing batch 179: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,758 - INFO - Processing batch 180/240 (100 items)
# 2025-06-13 15:37:49,759 - ERROR - Error processing batch 180: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,759 - INFO - Processing batch 181/240 (100 items)
# 2025-06-13 15:37:49,760 - ERROR - Error processing batch 181: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,761 - INFO - Processing batch 182/240 (100 items)
# 2025-06-13 15:37:49,761 - ERROR - Error processing batch 182: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,766 - INFO - Processing batch 183/240 (100 items)
# 2025-06-13 15:37:49,767 - ERROR - Error processing batch 183: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,768 - INFO - Processing batch 184/240 (100 items)
# 2025-06-13 15:37:49,769 - ERROR - Error processing batch 184: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,770 - INFO - Processing batch 185/240 (100 items)
# 2025-06-13 15:37:49,770 - ERROR - Error processing batch 185: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,771 - INFO - Processing batch 186/240 (100 items)
# 2025-06-13 15:37:49,771 - ERROR - Error processing batch 186: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,772 - INFO - Processing batch 187/240 (100 items)
# 2025-06-13 15:37:49,773 - ERROR - Error processing batch 187: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,773 - INFO - Processing batch 188/240 (100 items)
# 2025-06-13 15:37:49,774 - ERROR - Error processing batch 188: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,775 - INFO - Processing batch 189/240 (100 items)
# 2025-06-13 15:37:49,775 - ERROR - Error processing batch 189: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,776 - INFO - Processing batch 190/240 (100 items)
# 2025-06-13 15:37:49,776 - ERROR - Error processing batch 190: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,777 - INFO - Processing batch 191/240 (100 items)
# 2025-06-13 15:37:49,778 - ERROR - Error processing batch 191: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,778 - INFO - Processing batch 192/240 (100 items)
# 2025-06-13 15:37:49,779 - ERROR - Error processing batch 192: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,780 - INFO - Processing batch 193/240 (100 items)
# 2025-06-13 15:37:49,780 - ERROR - Error processing batch 193: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,781 - INFO - Processing batch 194/240 (100 items)
# 2025-06-13 15:37:49,781 - ERROR - Error processing batch 194: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,782 - INFO - Processing batch 195/240 (100 items)
# 2025-06-13 15:37:49,783 - ERROR - Error processing batch 195: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,785 - INFO - Processing batch 196/240 (100 items)
# 2025-06-13 15:37:49,785 - ERROR - Error processing batch 196: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,786 - INFO - Processing batch 197/240 (100 items)
# 2025-06-13 15:37:49,787 - ERROR - Error processing batch 197: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,787 - INFO - Processing batch 198/240 (100 items)
# 2025-06-13 15:37:49,788 - ERROR - Error processing batch 198: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,789 - INFO - Processing batch 199/240 (100 items)
# 2025-06-13 15:37:49,789 - ERROR - Error processing batch 199: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,790 - INFO - Processing batch 200/240 (100 items)
# 2025-06-13 15:37:49,790 - ERROR - Error processing batch 200: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,791 - INFO - Processing batch 201/240 (100 items)
# 2025-06-13 15:37:49,792 - ERROR - Error processing batch 201: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,793 - INFO - Processing batch 202/240 (100 items)
# 2025-06-13 15:37:49,793 - ERROR - Error processing batch 202: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,794 - INFO - Processing batch 203/240 (100 items)
# 2025-06-13 15:37:49,795 - ERROR - Error processing batch 203: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,795 - INFO - Processing batch 204/240 (100 items)
# 2025-06-13 15:37:49,796 - ERROR - Error processing batch 204: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,797 - INFO - Processing batch 205/240 (100 items)
# 2025-06-13 15:37:49,797 - ERROR - Error processing batch 205: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,798 - INFO - Processing batch 206/240 (100 items)
# 2025-06-13 15:37:49,799 - ERROR - Error processing batch 206: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,800 - INFO - Processing batch 207/240 (100 items)
# 2025-06-13 15:37:49,802 - ERROR - Error processing batch 207: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,803 - INFO - Processing batch 208/240 (100 items)
# 2025-06-13 15:37:49,803 - ERROR - Error processing batch 208: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,804 - INFO - Processing batch 209/240 (100 items)
# 2025-06-13 15:37:49,805 - ERROR - Error processing batch 209: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,806 - INFO - Processing batch 210/240 (100 items)
# 2025-06-13 15:37:49,807 - ERROR - Error processing batch 210: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,809 - INFO - Processing batch 211/240 (100 items)
# 2025-06-13 15:37:49,809 - ERROR - Error processing batch 211: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,810 - INFO - Processing batch 212/240 (100 items)
# 2025-06-13 15:37:49,814 - ERROR - Error processing batch 212: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,815 - INFO - Processing batch 213/240 (100 items)
# 2025-06-13 15:37:49,815 - ERROR - Error processing batch 213: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,816 - INFO - Processing batch 214/240 (100 items)
# 2025-06-13 15:37:49,816 - ERROR - Error processing batch 214: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,817 - INFO - Processing batch 215/240 (100 items)
# 2025-06-13 15:37:49,818 - ERROR - Error processing batch 215: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,819 - INFO - Processing batch 216/240 (100 items)
# 2025-06-13 15:37:49,819 - ERROR - Error processing batch 216: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,820 - INFO - Processing batch 217/240 (100 items)
# 2025-06-13 15:37:49,820 - ERROR - Error processing batch 217: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,821 - INFO - Processing batch 218/240 (100 items)
# 2025-06-13 15:37:49,822 - ERROR - Error processing batch 218: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,823 - INFO - Processing batch 219/240 (100 items)
# 2025-06-13 15:37:49,823 - ERROR - Error processing batch 219: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,824 - INFO - Processing batch 220/240 (100 items)
# 2025-06-13 15:37:49,825 - ERROR - Error processing batch 220: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,826 - INFO - Processing batch 221/240 (100 items)
# 2025-06-13 15:37:49,826 - ERROR - Error processing batch 221: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,828 - INFO - Processing batch 222/240 (100 items)
# 2025-06-13 15:37:49,828 - ERROR - Error processing batch 222: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,829 - INFO - Processing batch 223/240 (100 items)
# 2025-06-13 15:37:49,830 - ERROR - Error processing batch 223: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,830 - INFO - Processing batch 224/240 (100 items)
# 2025-06-13 15:37:49,831 - ERROR - Error processing batch 224: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,832 - INFO - Processing batch 225/240 (100 items)
# 2025-06-13 15:37:49,832 - ERROR - Error processing batch 225: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,833 - INFO - Processing batch 226/240 (100 items)
# 2025-06-13 15:37:49,833 - ERROR - Error processing batch 226: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,840 - INFO - Processing batch 227/240 (100 items)
# 2025-06-13 15:37:49,840 - ERROR - Error processing batch 227: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,841 - INFO - Processing batch 228/240 (100 items)
# 2025-06-13 15:37:49,842 - ERROR - Error processing batch 228: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,843 - INFO - Processing batch 229/240 (100 items)
# 2025-06-13 15:37:49,844 - ERROR - Error processing batch 229: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,844 - INFO - Processing batch 230/240 (100 items)
# 2025-06-13 15:37:49,845 - ERROR - Error processing batch 230: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,846 - INFO - Processing batch 231/240 (100 items)
# 2025-06-13 15:37:49,846 - ERROR - Error processing batch 231: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,847 - INFO - Processing batch 232/240 (100 items)
# 2025-06-13 15:37:49,851 - ERROR - Error processing batch 232: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,851 - INFO - Processing batch 233/240 (100 items)
# 2025-06-13 15:37:49,852 - ERROR - Error processing batch 233: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,853 - INFO - Processing batch 234/240 (100 items)
# 2025-06-13 15:37:49,853 - ERROR - Error processing batch 234: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,854 - INFO - Processing batch 235/240 (100 items)
# 2025-06-13 15:37:49,854 - ERROR - Error processing batch 235: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,855 - INFO - Processing batch 236/240 (100 items)
# 2025-06-13 15:37:49,856 - ERROR - Error processing batch 236: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,857 - INFO - Processing batch 237/240 (100 items)
# 2025-06-13 15:37:49,858 - ERROR - Error processing batch 237: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,858 - INFO - Processing batch 238/240 (100 items)
# 2025-06-13 15:37:49,859 - ERROR - Error processing batch 238: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,860 - INFO - Processing batch 239/240 (100 items)
# 2025-06-13 15:37:49,860 - ERROR - Error processing batch 239: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,861 - INFO - Processing batch 240/240 (79 items)
# 2025-06-13 15:37:49,862 - ERROR - Error processing batch 240: asyncio.run() cannot be called from a running event loop
# 2025-06-13 15:37:49,900 - INFO - === SCRAPING COMPLETE ===
# 2025-06-13 15:37:49,901 - INFO - Attempted to scrape: 23979
# 2025-06-13 15:37:49,902 - INFO - Successful requests: 0
# 2025-06-13 15:37:49,902 - INFO - Failed requests: 23979
# 2025-06-13 15:37:49,903 - INFO - New video records saved: 0
# 2025-06-13 15:37:49,904 - INFO - Success rate: 0.0%
